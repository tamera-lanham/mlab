# %%
import tokenizer
from tqdm import tqdm
import re
from collections import Counter

# %%
def corpus_common_tokens(corpus, n=3*1e5):
    counter = Counter()
    for text in corpus:
        tokens = re.findall(r"\w+|[^\w\s]", text)
        counter.update(tokens)
    tokens, counts = zip(*counter.most_common(int(n)))
    return tokens


common_tokens = corpus_common_tokens(tokenizer.corpus)
tokenizer.test_tokenizer_from_corpus_fn(corpus_common_tokens)

# %%
class Tokenizer:
    
    def __init__(self, token_list): # token_list: List[{“piece”:str, ”id”:int}]
        self.token_list = token_list
        self.token_dict = {d['id']: d['piece'] for d in token_list}
        self.reverse_token_dict = {v: k for k,v in self.token_dict.items()}
        self.unk = '[UNK]'
        self.unk_id = 3
        
    def decode(self, ids):
        return ''.join([self.token_dict.get(id_, self.unk) for id_ in ids])
    
    def tokenize(self, string):
        tokens = re.findall(r"\w+|[^\w\s]", string)
        return [self.reverse_token_dict.get(token, self.unk_id) for token in tokens]
        
tokenizer.test_tokenizer(Tokenizer)

# %%
class BPETokenizer(Tokenizer):
    
    def __init__(self, token_list, k=int(1e3)):
        super().__init__(token_list)
        self.k = k
        
    def tokenize(self, string):
        merges, tokens = 0, list(string)
        while merges <= self.k:
            for idx, token in enumerate(tokens):
                # Oh we should merge idx and idx+1!
                any_merges=False
                if idx+1 < len(tokens):
                    print(idx, len(tokens))
                    if self.reverse_token_dict.get(token + tokens[idx+1], False):
                        merge_temp = token + tokens[idx+1]
                        tokens[idx] = merge_temp
                        tokens.pop(idx+1)
                        merges += 1
                        any_merges = True
                        break
            if not any_merges: break
        return tokens
    
    #Make a method from_corpus(corpus: List[str]) on your BPETokenizer class. 
    # It should break the texts into char tokens, 
    # then count the number of each pair of sequential token(char) in the corpus. 
    # Then create a new token that’s the concatenation of the two most common sequential tokens. 
    # Repeat this some number of times. 

    def from_corpus_old(self, corpus):
        tokens = [char for string in corpus for char in string]
        new_tokens = ['  ']  # ' ', ' ' -> '  '
        
        for i in range(self.k):
            pairs = [tokens[i-1] + token for i, token in enumerate(tokens, 1)]
            counter = Counter(pairs)
            new_token, _ = counter.most_common(1)[0]
            
            
    def from_corpus(self, corpus):
        tokens = [char for string in corpus for char in string]

        for i in tqdm(range(self.k)):
            pairs = [token + tokens[i+1] for i, token in enumerate(tokens[:-1])]
            
            d = {}
            for i, pair in enumerate(pairs):
                if pair not in d: d[pair] = []
                d[pair].append(i)
                
            most_common, most_common_i = max(d.items(), key=lambda pair: len(pair[1]))
            
            j, new_tokens = 0, []
            while j < len(tokens):
                if j in most_common_i: 
                    new_tokens.append(most_common)
                    j += 1
                else: new_tokens.append(tokens[j])
                j += 1
            
            tokens = new_tokens
            
        return tokens

# %% [markdown]
# ---

# %% [markdown]
# # Viterbi pseudocode
#
# - No substring of a string can be less likely than the string itself
#
#
# ```
#
# ```

# %%
reference = tokenizer.Tokenizer.from_corpus(tokenizer.corpus)
t = BPETokenizer(token_list=reference.token_list, k = 5000)

# %%
tokens = t.from_corpus(tokenizer.minicorpus)
# Out:
# 100%|██████████| 5000/5000 [02:53<00:00, 28.80it/s]

# %%
max([len(t) for t in tokens])
# Out:
# 11829

# %%
set([t for t in tokens if len(t) >= 10])
# Out:
# {'\n\n\n\n\nACT IV',
#  '\n\n                    ',
#  '\n    I am ',
#  '\n    Must ',
#  '\n    Than ',
#  '\n    That ',
#  '\n    This ',
#  '\n    Till ',
#  '\n    To give ',
#  '\n    We have ',
#  '\n    What ',
#  '\n    Which ',
#  '\n    displeasure',
#  '\n    of the ',
#  '\n    your ',
#  '\n  BERTRAM. ',
#  '\n  PAROLLES. ',
#  '              ',
#  '                                ',
#  '      Exeun',
#  "  PAROLLES. O, let me live,\n    And all the secrets of our camp I'll show,\n    Their force, their purposes. Nay, I'll speak that\n    Which you will wonder at.\n  FIRST SOLDIER. But wilt thou faithfully?\n  PAROLLES. If I do not, damn me.\n  FIRST SOLDIER. Acordo linta.\n    Come on; thou art granted space.\n                   Exit, PAROLLES guarded. A short alarum within\n  SECOND LORD. Go, tell the Count Rousillon and my brother\n    We have caught the woodcock, and will keep him muffled\n    Till we do hear from them.\n  SECOND SOLDIER. Captain, I will.\n  SECOND LORD. 'A will betray us all unto ourselves-\n    Inform on that.\n  SECOND SOLDIER. So I will, sir.\n  SECOND LORD. Till then I'll keep him dark and safely lock'd.\n                                                          Exeunt\n\n\n\n\nACT IV. SCENE 2.\nFlorence. The WIDOW'S house\n\nEnter BERTRAM and DIANA\n\n  BERTRAM. They told me that your name was Fontibell.\n  DIANA. No, my good lord, Diana.\n  BERTRAM. Titled goddess;\n    And worth it, with addition! But, fair soul,\n    In your fine frame hath love no quality?\n    If the quick fire of youth light not your mind,\n    You are no maiden, but a monument;\n    When you are dead, you should be such a one\n    As you are now, for you are cold and stern;\n    And now you should be as your mother was\n    When your sweet self was got.\n  DIANA. She then was honest.\n  BERTRAM. So should you be.\n  DIANA. No.\n    My mother did but duty; such, my lord,\n    As you owe to your wife.\n  BERTRAM. No more o'that!  \n    I prithee do not strive against my vows.\n    I was compell'd to her; but I love the\n    By love's own sweet constraint, and will for ever\n    Do thee all rights of service.\n  DIANA. Ay, so you serve us\n    Till we serve you; but when you have our roses\n    You barely leave our thorns to prick ourselves,\n    And mock us with our bareness.\n  BERTRAM. How have I sworn!\n  DIANA. 'Tis not the many oaths that makes the truth,\n    But the plain single vow that is vow'd true.\n    What is not holy, that we swear not by,\n    But take the High'st to witness. Then, pray you, tell me:\n    If I should swear by Jove's great attributes\n    I lov'd you dearly, would you believe my oaths\n    When I did love you ill? This has no holding,\n    To swear by him whom I protest to love\n    That I will work against him. Therefore your oaths\n    Are words and poor conditions, but unseal'd-\n    At least in my opinion.  \n  BERTRAM. Change it, change it;\n    Be not so holy-cruel. Love is holy;\n    And my integrity ne'er knew the crafts\n    That you do charge men with. Stand no more off,\n    But give thyself unto my sick desires,\n    Who then recovers. Say thou art mine, and ever\n    My love as it begins shall so persever.\n  DIANA. I see that men make ropes in such a scarre\n    That we'll forsake ourselves. Give me that ring.\n  BERTRAM. I'll lend it thee, my dear, but have no power\n    To give it from me.\n  DIANA. Will you not, my lord?\n  BERTRAM. It is an honour 'longing to our house,\n    Bequeathed down from many ancestors;\n    Which were the greatest obloquy i' th' world\n    In me to lose.\n  DIANA. Mine honour's such a ring:\n    My chastity's the jewel of our house,\n    Bequeathed down from many ancestors;\n    Which were the greatest obloquy i' th' world  \n    In me to lose. Thus your own proper wisdom\n    Brings in the champion Honour on my part\n    Against your vain assault.\n  BERTRAM. Here, take my ring;\n    My house, mine honour, yea, my life, be thine,\n    And I'll be bid by thee.\n  DIANA. When midnight comes, knock at my chamber window;\n    I'll order take my mother shall not hear.\n    Now will I charge you in the band of truth,\n    When you have conquer'd my yet maiden bed,\n    Remain there but an hour, nor speak to me:\n    My reasons are most strong; and you shall know them\n    When back again this ring shall be deliver'd.\n    And on your finger in the night I'll  ...
#  ' they are ',
#  ' this.\n  BERTRAM. ',
#  ' thousand ',
#  '!\n  FIRST SOLDIER',
#  ',\n    And ',
#  ',\n    But ',
#  ',\n    Dear ',
#  ',\n    Hath ',
#  ',\n    Not ',
#  ',\n    Since ',
#  ',\n    That ',
#  ',\n    The ',
#  ',\n    Was ',
#  ',\n    When ',
#  ',\n    Which ',
#  ',\n    Who ',
#  ',\n    Whose ',
#  ',\n    You ',
#  ',\n    and ',
#  ',\n    the ',
#  ', I pray you',
#  ', and bring ',
#  ', and now ',
#  ', and take ',
#  ', and that ',
#  ', and the ',
#  ', my good lord, ',
#  ', my liege',
#  ', my lord, ',
#  ', sir, if ',
#  ', sir, in ',
#  ', sir, that ',
#  ', so many; ',
#  '.\n\n                    ',
#  '.\n\n                      ',
#  '.\n\n                        ',
#  '.\n\n                      Enter a ',
#  '.\n                                    ',
#  '.\n                                          ',
#  '.\n                                            ',
#  '.\n                                                          Exeun',
#  '.\n                                          [',
#  '.\n    And ',
#  ".\n    I'll ",
#  '.\n    The ',
#  '.\n  BERTRAM',
#  '.\n  BERTRAM. ',
#  '.\n  BERTRAM. A ',
#  '.\n  BERTRAM. H',
#  '.\n  BERTRAM. I ',
#  '.\n  CLOWN. F',
#  '.\n  CLOWN. Indeed',
#  '.\n  COUNTESS',
#  '.\n  DIANA. I ',
#  '.\n  FIRST LORD. I ',
#  '.\n  FIRST SOLDIER',
#  '.\n  FIRST SOLDIER. ',
#  ".\n  FIRST SOLDIER. '",
#  ".\n  FIRST SOLDIER. Well, that's set down",
#  '.\n  FIRST SOLDIER. What ',
#  '.\n  GENTLEMAN',
#  '.\n  HELENA',
#  '.\n  KING. ',
#  '.\n  KING. T',
#  '.\n  KING. The ',
#  '.\n  KING. What ',
#  '.\n  LAFEU. ',
#  '.\n  LAFEU. I ',
#  '.\n  LAFEU. You beg ',
#  '.\n  PAROLLES',
#  '.\n  PAROLLES. ',
#  ".\n  PAROLLES. '",
#  '.\n  PAROLLES. I ',
#  '.\n  PAROLLES. My ',
#  '.\n  SECOND ',
#  '.\n  SECOND LORD. ',
#  '.\n  SECOND LORD. H',
#  '.\n  SECOND LORD. He ',
#  '.\nRousillon. The ',
#  ".\nRousillon. The COUNT'S palace",
#  '.  \n  BERTRAM. ',
#  '.  \n  FIRST SOLDIER',
#  '.  \n  HELENA',
#  '.  \n  SECOND LORD. ',
#  '.                ',
#  '.                                ',
#  '.                                        ',
#  '. He will ',
#  '. His Highness ',
#  '. How does your ',
#  '. I would ',
#  '. Prithee, ',
#  '. Shall I ',
#  '. Sir, for ',
#  '. There is ',
#  '. We must ',
#  ". Well, that's set down",
#  ';\n    And ',
#  ';\n    For ',
#  ';\n    The ',
#  ';\n    Which ',
#  ';  \n    And ',
#  ';  \n    Our ',
#  '; and she ',
#  '; but when ',
#  '; thou art ',
#  '; we shall ',
#  '?\n  BERTRAM. ',
#  "?\n  BERTRAM. She's ",
#  '?\n  FIRST LORD. ',
#  '?\n  FIRST SOLDIER',
#  '?\n  GENTLEMAN',
#  '?\n  PAROLLES',
#  '?\n  PAROLLES. ',
#  '?\n  PAROLLES. I ',
#  '?\n  SECOND LORD. ',
#  'ATTENDANTS',
#  'ATTENDANTS\n\n  ',
#  'Ay, and the ',
#  'BERTRAM and ',
#  "COUNT'S palace",
#  'COUNTESS, LAFEU',
#  'Captain Du',
#  'Captain Dumain',
#  'Count Rousillon',
#  'Count Rousillon ',
#  "Count's a fool",
#  'DISTRIBUTED ',
#  'Demand of him ',
#  'ELECTRONIC ',
#  'Enter BERTRAM',
#  'FIRST SOLDIER',
#  'Five or six',
#  'Florentine',
#  "Fortune's ",
#  'HELENA, WIDOW, and ',
#  'HELENA. That ',
#  'I have not ',
#  'I have seen ',
#  'Marseilles, ',
#  "Nay, I'll ",
#  'PAROLLES. ',
#  "WIDOW'S house\n\nEnter ",
#  'a cardecue ',
#  'a great dea',
#  'aith, sir, ',
#  'an honest man ',
#  "are deceiv'd, my lord",
#  'atch of velve',
#  'beseech you, ',
#  'beseech your ',
#  'bring forth this ',
#  'can serve ',
#  'cannot be ',
#  'corrupt him ',
#  'could not ',
#  'd.\n  FIRST LORD. ',
#  'daughter; ',
#  'displeasur',
#  'displeasure ',
#  'e.\n  LAFEU',
#  'for France',
#  'gave it to ',
#  'give away ',
#  'good lord, ',
#  'he thinks ',
#  'her finger',
#  'her wear it',
#  'him hither',
#  'his Majest',
#  'his mother',
#  'his service',
#  "i' th'\n    stock",
#  'i, two hundred fifty each; ',
#  'in Florence',
#  'in the behal',
#  'is a good ',
#  'is not the ',
#  'it.\n  KING',
#  'lascivious ',
#  'last night',
#  'me\n    That ',
#  'mine honour',
#  'mine;\n    You give away ',
#  'mine; and ',
#  'my Lord Lafeu',
#  'noble Captain.\n  FIRST LORD. ',
#  'not\n    a ',
#  'not\n    to ',
#  'now, sir, ',
#  "of Fortune's ",
#  'of his\n    ',
#  'particular ',
#  "rapp'd in ",
#  'remembrance ',
#  'reputation ',
#  'reputation with the Duke',
#  's\n    That ',
#  's\n    Upon ',
#  's are forfe',
#  's.\n  CLOWN',
#  'say you to that?\n  PAROLLES. ',
#  'secrets of ',
#  'self, which ',
#  'shall we have ',
#  't\n\n\n\n\nACT IV',
#  't\n\n\n\n\nACT V SCENE ',
#  'the first ',
#  'themselves ',
#  'therefore, ',
#  'thing\n    ',
#  'thing, but ',
#  'to the King',
#  'two FRENCH LORDS',
#  'upon him! ',
#  'upon your ',
#  'wear your ',
#  'will be here ',
#  'with the Duk',
#  'with the Duke',
#  'woman here ',
#  'would have ',
#  'y.\n  COUNTESS',
#  'you are not ',
#  'you in the ',
#  'you must die',
#  'you shall ',
#  'you.\n  HELENA',
#  'your master'}

# %%
import pdb

def key(k):
    pdb.set_trace()
    
    

max(d.items(), key=lambda pair: len(pair[1]))
# Out:
# --Return--
# > <ipython-input-73-5c998fd87cb8>(4)key()->None
# -> pdb.set_trace()
# (Pdb)  k
# ('  ', [0, 28, 29, 30, 75, 76, 77, 129, 130, 131, 159, 202, 236, 267, 268, 269, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 369, 428, 429, 430, 487, 488, 489, 518, 553, 606, 607, 608, 626, 660, 723, 724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 863, 917, 951, 978, 979, 980, 1027, 1028, 1029, 1072, 1073, 1074, 1124, 1125, 1126, 1163, 1164, 1165, 1211, 1212, 1213, 1259, 1260, 1261, 1304, 1305, 1306, 1338, 1368, 1397, 1410, 1411, 1412, 1453, 1454, 1455, 1482, 1508, 1511, 1512, 1513, 1556, 1557, 1558, 1599, 1600, 1601, 1653, 1654, 1655, 1688, 1717, 1718, 1719, 1768, 1769, 1770, 1820, 1821, 1822, 1855, 1884, 1939, 1940, 1941, 1988, 1989, 1990, 2032, 2033, 2034, 2094, 2095, 2096, 2143, 2144, 2145, 2194, 2195, 2196, 2244, 2245, 2246, 2287, 2288, 2289, 2342, 2343, 2344, 2391, 2392, 2393, 2418, 2421, 2454, 2455, 2456, 2494, 2495, 2496, 2537, 2538, 2539, 2589, 2590, 2591, 2632, 2633, 2634, 2683, 2684, 2685, 2727, 2779, 2780, 2781, 2832, 2889, 2890, 2891, 2913, 2945, 2995, 2996, 2997, 3036, 3037, 3038, 3085, 3086, 3087, 3104, 3140, 3141, 3142, 3182, 3183, 3184, 3223, 3224, 3225, 3271, 3274, 3275, 3276, 3321, 3322, 3323, 3366, 3367, 3368, 3397, 3428, 3429, 3430, 3479, 3480, 3481, 3508, 3566, 3567, 3568, 3612, 3613, 3614, 3660, 3661, 3662, 3707, 3708, 3709, 3754, 3755, 3756, 3810, 3811, 3812, 3860, 3861, 3862, 3905, 3906, 3907, 3950, 3951, 3952, 3994, 3995, 3996, 4043, 4044, 4045, 4091, 4152, 4155, 4213, 4214, 4215, 4240, 4241, 4242, 4285, 4286, 4287, 4332, 4333, 4334, 4382, 4383, 4384, 4436, 4437, 4438, 4488, 4489, 4490, 4532, 4533, 4534, 4577, 4578, 4579, 4618, 4619, 4620, 4621, 4622, 4623, 4624, 4625, 4626, 4627, 4628, 4629, 4630, 4631, 4632, 4633, 4634, 4635, 4739, 4798, 4866, 4867, 4868, 4932, 4933, 4934, 4961, 5031, 5032, 5033, 5071, 5141, 5142, 5143, 5209, 5210, 5211, 5277, 5278, 5279, 5291, 5361, 5362, 5363, 5372, 5442, 5443, 5444, 5509, 5510, 5511, 5577, 5578, 5579, 5634, 5699, 5702, 5703, 5704, 5726, 5796, 5797, 5798, 5866, 5867, 5868, 5930, 5931, 5932, 5992, 5993, 5994, 6005, 6075, 6076, 6077, 6142, 6211, 6281, 6282, 6283, 6345, 6346, 6347, 6410, 6474, 6475, 6476, 6518, 6579, 6631, 6684, 6748, 6749, 6750, 6789, 6854, 6857, 6858, 6859, 6877, 6942, 6943, 6944, 6958, 7025, 7026, 7027, 7091, 7092, 7093, 7151, 7152, 7153, 7219, 7220, 7221, 7288, 7289, 7290, 7329, 7366, 7431, 7432, 7433, 7498, 7499, 7500, 7560, 7561, 7562, 7613, 7665, 7729, 7730, 7731, 7774, 7836, 7901, 7902, 7903, 7912, 7915, 7984, 7985, 7986, 8052, 8053, 8054, 8112, 8182, 8183, 8184, 8248, 8249, 8250, 8316, 8317, 8318, 8334, 8335, 8336, 8337, 8338, 8339, 8340, 8341, 8342, 8343, 8344, 8345, 8346, 8347, 8348, 8349, 8350, 8351, 8352, 8353, 8354, 8375, 8376, 8377, 8409, 8478, 8479, 8480, 8545, 8546, 8547, 8609, 8679, 8680, 8681, 8711, 8775, 8776, 8777, 8805, 8806, 8807, 8808, 8809, 8810, 8811, 8812, 8813, 8814, 8815, 8816, 8817, 8818, 8819, 8820, 8821, 8822, 8823, 8824, 8825, 8826, 8827, 8842, 8846, 8847, 8848, 8893, 8961, 8962, 8963, 9031, 9032, 9033, 9100, 9101, 9102, 9163, 9164, 9165, 9232, 9233, 9234, 9302, 9303, 9304, 9311, 9380, 9381, 9382, 9442, 9512, 9513, 9514, 9580, 9581, 9582, 9643, 9644, 9645, 9693, 9724, 9743, 9760, 9761, 9762, 9802, 9868, 9869, 9870, 9914, 9979, 9982, 9983, 9984, 10051, 10052, 10053, 10116, 10117, 10118, 10181, 10182, 10183, 10249, 10250, 10251, 10299, 10333, 10401, 10402, 10403, 10468, 10469, 10470, 10503, 10504, 10505, 10506, 10507, 10508, 10509, 10510, 10511, 10512, 10513, 10514, 10515, 10516, 10517, 10518, 10519, 10520, 10550, 10551, 10552, 10553, 10554, 10555, 10556, 10557, 10558, 10559, 10560, 10561, 10562, 10563, 10564, 10565, 10566, 10598, 10663, 10722, 10792, 10793, 10794, 10801, 10866, 10867, 10868, 10912, 10945, 10948, 10987, 11053, 11054, 11055, 11103,  ...
# (Pdb)  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-73-5c998fd87cb8> in <module>
#       6
#       7
# ----> 8 max(d.items(), key=key)
#
# <ipython-input-73-5c998fd87cb8> in key(k)
#       2
#       3 def key(k):
# ----> 4     pdb.set_trace()
#       5
#       6
#
# /usr/lib/python3.8/bdb.py in trace_dispatch(self, frame, event, arg)
#      90             return self.dispatch_call(frame, arg)
#      91         if event == 'return':
# ---> 92             return self.dispatch_return(frame, arg)
#      93         if event == 'exception':
#      94             return self.dispatch_exception(frame, arg)
#
# /usr/lib/python3.8/bdb.py in dispatch_return(self, frame, arg)
#     152             finally:
#     153                 self.frame_returning = None
# --> 154             if self.quitting: raise BdbQuit
#     155             # The user issued a 'next' or 'until' command.
#     156             if self.stopframe is frame and self.stoplineno != -1:
#
# BdbQuit:

# %%
counter.most_common(1)[0]
# Out:
# ('  ', 10896)

# %%
corpus = tokenizer.minicorpus
tokens = [char for string in corpus for char in string]

# %%
t.from_corpus(corpus)
# Out:
#   File "<ipython-input-14-b5bcae41da3c>", line 1
#     [ *word.split("") for word in corpus ]
#       ^
# SyntaxError: iterable unpacking cannot be used in comprehension

# %%
t.tokenize("I am a chicken!")
# Out:
# 0 15
# 1 15
# 2 15
# 0 14
# 1 14
# 2 14
# 3 14
# 4 14
# 5 14
# 6 14
# 7 14
# 8 14
# 9 14
# 10 14
# 11 14
# 0 13
# 1 13
# 2 13
# 3 13
# 4 13
# 5 13
# 6 13
# 7 13
# 8 13
# 9 13
# 10 13
# 0 12
# 1 12
# 2 12
# 3 12
# 4 12
# 5 12
# 6 12
# 7 12
# 8 12
# 9 12
# 10 12
# ['I', ' ', 'am', ' ', 'a', ' ', 'c', 'h', 'i', 'c', 'ken', '!']

# %%
t.tokenize("I can do spit today")
# Out:
# 0 19
# 1 19
# 2 19
# 3 19
# 0 18
# 1 18
# 2 18
# 0 17
# 1 17
# 2 17
# 3 17
# 4 17
# 0 16
# 1 16
# 2 16
# 3 16
# 4 16
# 5 16
# 6 16
# 7 16
# 8 16
# 0 15
# 1 15
# 2 15
# 3 15
# 4 15
# 5 15
# 6 15
# 7 15
# 0 14
# 1 14
# 2 14
# 3 14
# 4 14
# 5 14
# 6 14
# 0 13
# 1 13
# 2 13
# 3 13
# 4 13
# 5 13
# 6 13
# 7 13
# 8 13
# 0 12
# 1 12
# 2 12
# 3 12
# 4 12
# 5 12
# 6 12
# 7 12
# 8 12
# 0 11
# 1 11
# 2 11
# 3 11
# 4 11
# 5 11
# 6 11
# 7 11
# 8 11
# 9 11
# 0 10
# 1 10
# 2 10
# 3 10
# 4 10
# 5 10
# 6 10
# 7 10
# 8 10
# 0 9
# 1 9
# 2 9
# 3 9
# 4 9
# 5 9
# 6 9
# 7 9
# ['I', ' ', 'can', ' ', 'do', ' ', 'spit', ' ', 'today']

# %%
import json

known_dist = {}
with open('sentencepiece.json', 'r') as f:
    known_dist = json.load(f)


def viterbi_this(known_dist, sentence):
    # Do Viterbi things
    # 1. count up the possible tokenization permutation for the sentence
    tokens = [char for string in corpus for char in sentence]
    
    token_v_score = [(char, score) for char in tokens]
    #loop up on a
    
    # 2. See which permutation has the lowest entropy
    # 3. use said "lowest entropy" permutation

# %%
known_dist.sort(key = lambda x: -x['score'])

# %%
known_dist
# Out:
# [{'piece': '<pad>', 'id': 0, 'score': 0.0, 'type': 3},
#  {'piece': '<unk>', 'id': 1, 'score': 0.0, 'type': 2},
#  {'piece': '[CLS]', 'id': 2, 'score': 0.0, 'type': 3},
#  {'piece': '[SEP]', 'id': 3, 'score': 0.0, 'type': 3},
#  {'piece': '[MASK]', 'id': 4, 'score': 0.0, 'type': 3},
#  {'piece': '(', 'id': 5, 'score': 0.0, 'type': 4},
#  {'piece': ')', 'id': 6, 'score': 0.0, 'type': 4},
#  {'piece': '"', 'id': 7, 'score': 0.0, 'type': 4},
#  {'piece': '-', 'id': 8, 'score': 0.0, 'type': 4},
#  {'piece': '.', 'id': 9, 'score': 0.0, 'type': 4},
#  {'piece': '–', 'id': 10, 'score': 0.0, 'type': 4},
#  {'piece': '£', 'id': 11, 'score': 0.0, 'type': 4},
#  {'piece': '€', 'id': 12, 'score': 0.0, 'type': 4},
#  {'piece': '▁', 'id': 13, 'score': -2.1889710426330566, 'type': 1},
#  {'piece': '▁the', 'id': 14, 'score': -3.07045841217041, 'type': 1},
#  {'piece': ',', 'id': 15, 'score': -3.1902313232421875, 'type': 1},
#  {'piece': '▁of', 'id': 16, 'score': -3.8403830528259277, 'type': 1},
#  {'piece': '▁and', 'id': 17, 'score': -3.901123523712158, 'type': 1},
#  {'piece': 's', 'id': 18, 'score': -3.98744797706604, 'type': 1},
#  {'piece': '▁in', 'id': 19, 'score': -4.025292873382568, 'type': 1},
#  {'piece': '▁to', 'id': 20, 'score': -4.119879245758057, 'type': 1},
#  {'piece': '▁a', 'id': 21, 'score': -4.120291709899902, 'type': 1},
#  {'piece': "'", 'id': 22, 'score': -4.669830322265625, 'type': 1},
#  {'piece': '▁was', 'id': 23, 'score': -4.71638298034668, 'type': 1},
#  {'piece': '▁he', 'id': 24, 'score': -5.018745422363281, 'type': 1},
#  {'piece': '▁is', 'id': 25, 'score': -5.13440465927124, 'type': 1},
#  {'piece': '▁for', 'id': 26, 'score': -5.137171745300293, 'type': 1},
#  {'piece': '▁on', 'id': 27, 'score': -5.1661200523376465, 'type': 1},
#  {'piece': '▁as', 'id': 28, 'score': -5.172532558441162, 'type': 1},
#  {'piece': '▁with', 'id': 29, 'score': -5.26673698425293, 'type': 1},
#  {'piece': '▁that', 'id': 30, 'score': -5.276981353759766, 'type': 1},
#  {'piece': '▁i', 'id': 31, 'score': -5.285733699798584, 'type': 1},
#  {'piece': '▁it', 'id': 32, 'score': -5.319027423858643, 'type': 1},
#  {'piece': '▁his', 'id': 33, 'score': -5.330879211425781, 'type': 1},
#  {'piece': '▁by', 'id': 34, 'score': -5.466182708740234, 'type': 1},
#  {'piece': '▁at', 'id': 35, 'score': -5.502425670623779, 'type': 1},
#  {'piece': '▁her', 'id': 36, 'score': -5.630719184875488, 'type': 1},
#  {'piece': '▁from', 'id': 37, 'score': -5.644594192504883, 'type': 1},
#  {'piece': 't', 'id': 38, 'score': -5.728087425231934, 'type': 1},
#  {'piece': '▁she', 'id': 39, 'score': -5.741541385650635, 'type': 1},
#  {'piece': '▁an', 'id': 40, 'score': -5.971688270568848, 'type': 1},
#  {'piece': '▁had', 'id': 41, 'score': -5.985723972320557, 'type': 1},
#  {'piece': '▁you', 'id': 42, 'score': -5.995770454406738, 'type': 1},
#  {'piece': 'd', 'id': 43, 'score': -6.0267252922058105, 'type': 1},
#  {'piece': '▁be', 'id': 44, 'score': -6.031558036804199, 'type': 1},
#  {'piece': ':', 'id': 45, 'score': -6.069502830505371, 'type': 1},
#  {'piece': '▁were', 'id': 46, 'score': -6.074887275695801, 'type': 1},
#  {'piece': '▁but', 'id': 47, 'score': -6.152650356292725, 'type': 1},
#  {'piece': '▁this', 'id': 48, 'score': -6.177365303039551, 'type': 1},
#  {'piece': 'i', 'id': 49, 'score': -6.189263343811035, 'type': 1},
#  {'piece': '▁are', 'id': 50, 'score': -6.232006072998047, 'type': 1},
#  {'piece': '▁my', 'id': 51, 'score': -6.330941677093506, 'type': 1},
#  {'piece': '▁not', 'id': 52, 'score': -6.340751647949219, 'type': 1},
#  {'piece': '▁one', 'id': 53, 'score': -6.379505157470703, 'type': 1},
#  {'piece': '▁or', 'id': 54, 'score': -6.390121936798096, 'type': 1},
#  {'piece': '▁me', 'id': 55, 'score': -6.396585941314697, 'type': 1},
#  {'piece': '▁which', 'id': 56, 'score': -6.397637844085693, 'type': 1},
#  {'piece': '▁have', 'id': 57, 'score': -6.409730911254883, 'type': 1},
#  {'piece': 'a', 'id': 58, 'score': -6.421509742736816, 'type': 1},
#  {'piece': '▁they', 'id': 59, 'score': -6.42303466796875, 'type': 1},
#  {'piece': '?', 'id': 60, 'score': -6.423282146453857, 'type': 1},
#  {'piece': '▁him', 'id': 61, 'score': -6.461080551147461, 'type': 1},
#  {'piece': 'e', 'id': 62, 'score': -6.562606334686279, 'type': 1},
#  {'piece': '▁has', 'id': 63, 'score': -6.569113731384277, 'type': 1},
#  {'piece': '▁first', 'id': 64, 'score': -6.5800981521606445, 'type': 1},
#  {'piece': '▁all', 'id': 65, 'score': -6.584105491638184, 'type': 1},
#  {'piece': '▁their', 'id': 66, 'score': -6.593716621398926, 'type': 1},
#  {'piece': '▁also', 'id': 67, 'score': -6.609805107116699, 'type': 1},
#  {'piece': 'ing', 'id': 68, 'score': -6.62164831161499, 'type': 1},
#  {'piece': 'ed', 'id': 69, 'score': -6.639188289642334, 'type': 1},
#  {'piece': '▁out', 'id': 70, 'score': -6.6434645652771, 'type': 1},
#  {'piece': '▁up', 'id': 71, 'score': -6.655246734619141, 'type': 1},
#  {'piece': '▁who', 'id': 72, 'score': -6.665343284606934, 'type': 1},
#  {'piece': ';', 'id': 73, 'score': -6.677074909210205, 'type': 1},
#  {'piece': '▁been', 'id': 74, 'score': -6.690547466278076, 'type': 1},
#  {'piece': '▁after', 'id': 75, 'score': -6.701145648956299, 'type': 1},
#  {'piece': '▁when', 'id': 76, 'score': -6.714375972747803, 'type': 1},
#  {'piece': '▁into', 'id': 77, 'score': -6.74838924407959, 'type': 1},
#  {'piece': '▁new', 'id': 78, 'score': -6.749521732330322, 'type': 1},
#  {'piece': 'm', 'id': 79, 'score': -6.752879619598389, 'type': 1},
#  {'piece': '▁there', 'id': 80, 'score': -6.770188331604004, 'type': 1},
#  {'piece': '▁two', 'id': 81, 'score': -6.807394027709961, 'type': 1},
#  {'piece': '▁its', 'id': 82, 'score': -6.810059070587158, 'type': 1},
#  {'piece': '▁would', 'id': 83, 'score': -6.839665412902832, 'type': 1},
#  {'piece': '▁over', 'id': 84, 'score': -6.8716654777526855, 'type': 1},
#  {'piece': '▁time', 'id': 85, 'score': -6.872101306915283, 'type': 1},
#  {'piece': '▁so', 'id': 86, 'score': -6.882864475250244, 'type': 1},
#  {'piece': '▁said', 'id': 87, 'score': -6.926548480987549, 'type': 1},
#  {'piece': '▁about', 'id': 88, 'score': -6.929421424865723, 'type': 1},
#  {'piece': '▁other', 'id': 89, 'score': -6.934679985046387, 'type': 1},
#  {'piece': '▁no', 'id': 90, 'score': -6.951066493988037, 'type': 1},
#  {'piece': '▁more', 'id': 91, 'score': -6.974709987640381, 'type': 1},
#  {'piece': '▁can', 'id': 92, 'score': -6.987176418304443, 'type': 1},
#  {'piece': 'y', 'id': 93, 'score': -6.997949123382568, 'type': 1},
#  {'piece': '▁then', 'id': 94, 'score': -7.015105247497559, 'type': 1},
#  {'piece': '▁we', 'id': 95, 'score': -7.01777982711792, 'type': 1},
#  {'piece': 'th', 'id': 96, 'score': -7.031699180603027, 'type': 1},
#  {'piece': '▁back', 'id': 97, 'score': -7.05420446395874, 'type': 1},
#  {'piece': '▁what', 'id': 98, 'score': -7.074428558349609, 'type': 1},
#  {'piece': 're', 'id': 99, 'score': -7.0936713218688965, 'type': 1},
#  {'piece': '▁if', 'id': 100, 'score': -7.096348285675049, 'type': 1},
#  {'piece': '▁like', 'id': 101, 'score': -7.104947090148926, 'type': 1},
#  {'piece': 'ly', 'id': 102, 'score': -7.1178975105285645, 'type': 1},
#  {'piece': 'n', 'id': 103, 'score': -7.131936550140381, 'type': 1},
#  {'piece': '▁only', 'id': 104, 'score': -7.145911693572998, 'type': 1},
#  {'piece': '▁them', 'id': 105, 'score': -7.179184913635254, 'type': 1},
#  {'piece': 'er', 'id': 106, 'score': -7.184884548187256, 'type': 1},
#  {'piece': '▁do', 'id': 107, 'score': -7.190641403198242, 'type': 1},
#  {'piece': 'in', 'id': 108, 'score': -7.200558662414551, 'type': 1},
#  {'piece': '▁some', 'id': 109, 'score': -7.2232561111450195, 'type': 1},
#  {'piece': '▁could', 'id': 110, 'score': -7.232329845428467, 'type': 1},
#  {'piece': 'o', 'id': 111, 'score': -7.241729259490967, 'type': 1},
#  {'piece': '▁during', 'id': 112, 'score': -7.273820400238037, 'type': 1},
#  {'piece': '▁where', 'id': 113, 'score': -7.283714294433594, 'type': 1},
#  {'piece': '▁just', 'id': 114, 'score': -7.287729263305664, 'type': 1},
#  {'piece': '▁before', 'id': 115, 'score': -7.295721054077148, 'type': 1},
#  {'piece': '▁school', 'id': 116, 'score': -7.308872699737549, 'type': 1},
#  {'piece': '▁made', 'id': 117, 'score': -7.320419788360596, 'type': 1},
#  {'piece': '/', 'id': 118, 'score': -7.321349620819092, 'type': 1},
#  {'piece': '▁than', 'id': 119, 'score': -7.325694561004639, 'type': 1},
#  {'piece': '▁through', 'id': 120, 'score': -7.334000110626221, 'type': 1},
#  {'piece': '▁de', 'id': 121, 'score': -7.334046363830566, 'type': 1},
#  {'piece': '▁years', 'id': 122, 'score': -7.388918876647949, 'type': 1},
#  {'piece': '▁may', 'id': 123, 'score': -7.3909687995910645, 'type': 1},
#  {'piece': 'the', 'id': 124, 'score': -7.401867389678955, 'type': 1},
#  {'piece': '▁down', 'id': 125, 'score': -7.405778884887695, 'type': 1},
#  {'piece': '▁world', 'id': 126, 'score': -7.409426689147949, 'type': 1},
#  {'piece': '▁most', 'id': 127, 'score': -7.415700912475586, 'type': 1},
#  {'piece': '▁between', 'id': 128, 'score': -7.4298624992370605, 'type': 1},
#  {'piece': '▁will', 'id': 129, 'score': -7.432695388793945, 'type': 1},
#  {'piece': '▁now', 'id': 130, 'score': -7.450641632080078, 'type': 1},
#  {'piece': '▁under', 'id': 131, 'score': -7.457030296325684, 'type': 1},
#  {'piece': '▁three', 'id': 132, 'score': -7.459658622741699, 'type': 1},
#  {'piece': '▁while', 'id': 133, 'score': -7.464503288269043, 'type': 1},
#  {'piece': '▁well', 'id': 134, 'score': -7.470224380493164, 'type': 1},
#  {'piece': '2', 'id': 135, 'score': -7.482062816619873, 'type': 1},
#  {'piece': '▁city', 'id': 136, 'score': -7.526623725891113, 'type': 1},
#  {'piece': '▁1', 'id': 137, 'score': -7.529170989990234, 'type': 1},
#  {'piece': '▁later', 'id': 138, 'score': -7.533838272094727, 'type': 1},
#  {'piece': 'r', 'id': 139, 'score': -7.543635368347168, 'type': 1},
#  {'piece': '▁around', 'id': 140, 'score': -7.550468921661377, 'type': 1},
#  {'piece': '▁part', 'id': 141, 'score': -7.564833164215088, 'type': 1},
#  {'piece': '▁being', 'id': 142, 'score': -7.565091133117676, 'type': 1},
#  {'piece': '▁know', 'id': 143, 'score': -7.566204071044922, 'type': 1},
#  {'piece': '▁did', 'id': 144, 'score': -7.568881988525391, 'type': 1},
#  {'piece': '▁such', 'id': 145, 'score': -7.580020427703857, 'type': 1},
#  {'piece': '▁state', 'id': 146, 'score': -7.580413818359375, 'type': 1},
#  {'piece': '▁used', 'id': 147, 'score': -7.580532550811768, 'type': 1},
#  {'piece': '▁people', 'id': 148, 'score': -7.5884013175964355, 'type': 1},
#  {'piece': '▁against', 'id': 149, 'score': -7.594408988952637, 'type': 1},
#  {'piece': 'c', 'id': 150, 'score': -7.601968765258789, 'type': 1},
#  {'piece': '▁many', 'id': 151, 'score': -7.606905460357666, 'type': 1},
#  {'piece': '▁national', 'id': 152, 'score': -7.608926296234131, 'type': 1},
#  {'piece': '▁second', 'id': 153, 'score': -7.619673252105713, 'type': 1},
#  {'piece': '▁your', 'id': 154, 'score': -7.627218246459961, 'type': 1},
#  {'piece': '▁university', 'id': 155, 'score': -7.629205226898193, 'type': 1},
#  {'piece': '▁both', 'id': 156, 'score': -7.637609004974365, 'type': 1},
#  {'piece': '▁head', 'id': 157, 'score': -7.651505947113037, 'type': 1},
#  {'piece': '▁these', 'id': 158, 'score': -7.658509254455566, 'type': 1},
#  {'piece': '▁year', 'id': 159, 'score': -7.663209438323975, 'type': 1},
#  {'piece': 'es', 'id': 160, 'score': -7.666430950164795, 'type': 1},
#  {'piece': '▁way', 'id': 161, 'score': -7.679833889007568, 'type': 1},
#  {'piece': '▁go', 'id': 162, 'score': -7.688291072845459, 'type': 1},
#  {'piece': '▁until', 'id': 163, 'score': -7.690299034118652, 'type': 1},
#  {'piece': '▁get', 'id': 164, 'score': -7.693119049072266, 'type': 1},
#  {'piece': '1', 'id': 165, 'score': -7.693806171417236, 'type': 1},
#  {'piece': '▁even', 'id': 166, 'score': -7.6986894607543945, 'type': 1},
#  {'piece': '▁known', 'id': 167, 'score': -7.707066059112549, 'type': 1},
#  {'piece': '▁off', 'id': 168, 'score': -7.707283020019531, 'type': 1},
#  {'piece': '▁man', 'id': 169, 'score': -7.712987422943115, 'type': 1},
#  {'piece': '▁work', 'id': 170, 'score': -7.7131500244140625, 'type': 1},
#  {'piece': '▁film', 'id': 171, 'score': -7.7206830978393555, 'type': 1},
#  {'piece': '▁2', 'id': 172, 'score': -7.726144313812256, 'type': 1},
#  {'piece': '▁team', 'id': 173, 'score': -7.730968952178955, 'type': 1},
#  {'piece': '▁still', 'id': 174, 'score': -7.743301868438721, 'type': 1},
#  {'piece': '▁long', 'id': 175, 'score': -7.746030807495117, 'type': 1},
#  {'piece': '▁war', 'id': 176, 'score': -7.755843639373779, 'type': 1},
#  {'piece': 'man', 'id': 177, 'score': -7.761481285095215, 'type': 1},
#  {'piece': '▁became', 'id': 178, 'score': -7.764931678771973, 'type': 1},
#  {'piece': '▁since', 'id': 179, 'score': -7.765870094299316, 'type': 1},
#  {'piece': '▁south', 'id': 180, 'score': -7.766265392303467, 'type': 1},
#  {'piece': '▁united', 'id': 181, 'score': -7.767479419708252, 'type': 1},
#  {'piece': '▁us', 'id': 182, 'score': -7.780489921569824, 'type': 1},
#  {'piece': '▁high', 'id': 183, 'score': -7.780867099761963, 'type': 1},
#  {'piece': '▁how', 'id': 184, 'score': -7.781338691711426, 'type': 1},
#  {'piece': '▁because', 'id': 185, 'score': -7.782547473907471, 'type': 1},
#  {'piece': '▁any', 'id': 186, 'score': -7.784655570983887, 'type': 1},
#  {'piece': '!', 'id': 187, 'score': -7.793766975402832, 'type': 1},
#  {'piece': '▁again', 'id': 188, 'score': -7.794539451599121, 'type': 1},
#  {'piece': '▁american', 'id': 189, 'score': -7.808248043060303, 'type': 1},
#  {'piece': '▁family', 'id': 190, 'score': -7.80874490737915, 'type': 1},
#  {'piece': '▁house', 'id': 191, 'score': -7.813141345977783, 'type': 1},
#  {'piece': 'al', 'id': 192, 'score': -7.821590423583984, 'type': 1},
#  {'piece': '▁right', 'id': 193, 'score': -7.824173450469971, 'type': 1},
#  {'piece': '▁eyes', 'id': 194, 'score': -7.827173233032227, 'type': 1},
#  {'piece': 've', 'id': 195, 'score': -7.829625129699707, 'type': 1},
#  {'piece': '▁see', 'id': 196, 'score': -7.837514400482178, 'type': 1},
#  {'piece': 'k', 'id': 197, 'score': -7.848587512969971, 'type': 1},
#  {'piece': '▁season', 'id': 198, 'score': -7.85122537612915, 'type': 1},
#  {'piece': '▁took', 'id': 199, 'score': -7.852779388427734, 'type': 1},
#  {'piece': '▁north', 'id': 200, 'score': -7.85922384262085, 'type': 1},
#  {'piece': '▁life', 'id': 201, 'score': -7.867621898651123, 'type': 1},
#  {'piece': '▁states', 'id': 202, 'score': -7.867995738983154, 'type': 1},
#  {'piece': '▁3', 'id': 203, 'score': -7.8735761642456055, 'type': 1},
#  {'piece': '▁name', 'id': 204, 'score': -7.876920223236084, 'type': 1},
#  {'piece': '▁same', 'id': 205, 'score': -7.881766319274902, 'type': 1},
#  {'piece': '▁each', 'id': 206, 'score': -7.893111228942871, 'type': 1},
#  {'piece': '▁however', 'id': 207, 'score': -7.893795013427734, 'type': 1},
#  {'piece': '▁day', 'id': 208, 'score': -7.894530296325684, 'type': 1},
#  {'piece': '▁place', 'id': 209, 'score': -7.896968364715576, 'type': 1},
#  {'piece': 'an', 'id': 210, 'score': -7.898983955383301, 'type': 1},
#  {'piece': 'll', 'id': 211, 'score': -7.900506973266602, 'type': 1},
#  {'piece': '▁much', 'id': 212, 'score': -7.905595779418945, 'type': 1},
#  {'piece': '▁home', 'id': 213, 'score': -7.909955024719238, 'type': 1},
#  {'piece': '▁group', 'id': 214, 'score': -7.910377502441406, 'type': 1},
#  {'piece': '▁including', 'id': 215, 'score': -7.915847301483154, 'type': 1},
#  {'piece': '▁found', 'id': 216, 'score': -7.926575660705566, 'type': 1},
#  {'piece': '▁area', 'id': 217, 'score': -7.93124532699585, 'type': 1},
#  {'piece': 'on', 'id': 218, 'score': -7.932888031005859, 'type': 1},
#  {'piece': 'en', 'id': 219, 'score': -7.9332356452941895, 'type': 1},
#  {'piece': 'b', 'id': 220, 'score': -7.935197353363037, 'type': 1},
#  {'piece': '▁don', 'id': 221, 'score': -7.938117504119873, 'type': 1},
#  {'piece': '▁four', 'id': 222, 'score': -7.938998222351074, 'type': 1},
#  {'piece': '▁didn', 'id': 223, 'score': -7.940306663513184, 'type': 1},
#  {'piece': '▁hand', 'id': 224, 'score': -7.944356441497803, 'type': 1},
#  {'piece': '▁left', 'id': 225, 'score': -7.9451375007629395, 'type': 1},
#  {'piece': '▁another', 'id': 226, 'score': -7.948366641998291, 'type': 1},
#  {'piece': '▁called', 'id': 227, 'score': -7.950814723968506, 'type': 1},
#  {'piece': '▁going', 'id': 228, 'score': -7.951108932495117, 'type': 1},
#  {'piece': '▁away', 'id': 229, 'score': -7.963186740875244, 'type': 1},
#  {'piece': '▁won', 'id': 230, 'score': -7.963527202606201, 'type': 1},
#  {'piece': '▁series', 'id': 231, 'score': -7.964580535888672, 'type': 1},
#  {'piece': '▁music', 'id': 232, 'score': -7.965966701507568, 'type': 1},
#  {'piece': '▁make', 'id': 233, 'score': -7.969881534576416, 'type': 1},
#  {'piece': '▁number', 'id': 234, 'score': -7.971346855163574, 'type': 1},
#  {'piece': '▁here', 'id': 235, 'score': -7.981332778930664, 'type': 1},
#  {'piece': '▁last', 'id': 236, 'score': -7.984688758850098, 'type': 1},
#  {'piece': '▁company', 'id': 237, 'score': -7.984898567199707, 'type': 1},
#  {'piece': '▁several', 'id': 238, 'score': -7.986128330230713, 'type': 1},
#  {'piece': '▁john', 'id': 239, 'score': -7.994099140167236, 'type': 1},
#  {'piece': '3', 'id': 240, 'score': -7.9953227043151855, 'type': 1},
#  {'piece': '▁end', 'id': 241, 'score': -7.997664451599121, 'type': 1},
#  {'piece': 'it', 'id': 242, 'score': -7.997814178466797, 'type': 1},
#  {'piece': '▁never', 'id': 243, 'score': -8.011713027954102, 'type': 1},
#  {'piece': '▁album', 'id': 244, 'score': -8.012520790100098, 'type': 1},
#  {'piece': 'you', 'id': 245, 'score': -8.016480445861816, 'type': 1},
#  {'piece': '▁best', 'id': 246, 'score': -8.019217491149902, 'type': 1},
#  {'piece': '▁take', 'id': 247, 'score': -8.020607948303223, 'type': 1},
#  {'piece': 'or', 'id': 248, 'score': -8.02608585357666, 'type': 1},
#  {'piece': '▁following', 'id': 249, 'score': -8.026646614074707, 'type': 1},
#  {'piece': '▁game', 'id': 250, 'score': -8.027846336364746, 'type': 1},
#  {'piece': 'no', 'id': 251, 'score': -8.032623291015625, 'type': 1},
#  {'piece': 'h', 'id': 252, 'score': -8.034906387329102, 'type': 1},
#  {'piece': '▁very', 'id': 253, 'score': -8.038044929504395, 'type': 1},
#  {'piece': '▁good', 'id': 254, 'score': -8.044915199279785, 'type': 1},
#  {'piece': 'l', 'id': 255, 'score': -8.047317504882812, 'type': 1},
#  {'piece': '▁district', 'id': 256, 'score': -8.05458927154541, 'type': 1},
#  {'piece': '▁played', 'id': 257, 'score': -8.05738353729248, 'type': 1},
#  {'piece': '▁own', 'id': 258, 'score': -8.057414054870605, 'type': 1},
#  {'piece': '▁want', 'id': 259, 'score': -8.061219215393066, 'type': 1},
#  {'piece': '▁began', 'id': 260, 'score': -8.063311576843262, 'type': 1},
#  {'piece': '▁released', 'id': 261, 'score': -8.064970970153809, 'type': 1},
#  {'piece': 'to', 'id': 262, 'score': -8.067658424377441, 'type': 1},
#  {'piece': 'g', 'id': 263, 'score': -8.069655418395996, 'type': 1},
#  {'piece': '5', 'id': 264, 'score': -8.07286262512207, 'type': 1},
#  {'piece': '▁little', 'id': 265, 'score': -8.076537132263184, 'type': 1},
#  {'piece': '▁too', 'id': 266, 'score': -8.07811164855957, 'type': 1},
#  {'piece': 'us', 'id': 267, 'score': -8.079915046691895, 'type': 1},
#  {'piece': '▁4', 'id': 268, 'score': -8.080121040344238, 'type': 1},
#  {'piece': '▁held', 'id': 269, 'score': -8.084221839904785, 'type': 1},
#  {'piece': '▁side', 'id': 270, 'score': -8.087630271911621, 'type': 1},
#  {'piece': '▁county', 'id': 271, 'score': -8.092172622680664, 'type': 1},
#  {'piece': '▁c', 'id': 272, 'score': -8.09340763092041, 'type': 1},
#  {'piece': '▁those', 'id': 273, 'score': -8.093783378601074, 'type': 1},
#  {'piece': '▁early', 'id': 274, 'score': -8.09395694732666, 'type': 1},
#  {'piece': '▁use', 'id': 275, 'score': -8.099573135375977, 'type': 1},
#  {'piece': '▁face', 'id': 276, 'score': -8.103350639343262, 'type': 1},
#  {'piece': '▁think', 'id': 277, 'score': -8.108543395996094, 'type': 1},
#  {'piece': '▁league', 'id': 278, 'score': -8.111355781555176, 'type': 1},
#  {'piece': '▁&', 'id': 279, 'score': -8.11233901977539, 'type': 1},
#  {'piece': '▁west', 'id': 280, 'score': -8.123568534851074, 'type': 1},
#  {'piece': '▁came', 'id': 281, 'score': -8.126768112182617, 'type': 1},
#  {'piece': '▁air', 'id': 282, 'score': -8.132853507995605, 'type': 1},
#  {'piece': '▁government', 'id': 283, 'score': -8.135549545288086, 'type': 1},
#  {'piece': '▁small', 'id': 284, 'score': -8.14218807220459, 'type': 1},
#  {'piece': '▁march', 'id': 285, 'score': -8.149076461791992, 'type': 1},
#  {'piece': '▁town', 'id': 286, 'score': -8.150150299072266, 'type': 1},
#  {'piece': '▁u', 'id': 287, 'score': -8.153229713439941, 'type': 1},
#  {'piece': '▁club', 'id': 288, 'score': -8.162888526916504, 'type': 1},
#  {'piece': '▁thought', 'id': 289, 'score': -8.167357444763184, 'type': 1},
#  {'piece': 'and', 'id': 290, 'score': -8.174901962280273, 'type': 1},
#  {'piece': 'u', 'id': 291, 'score': -8.179855346679688, 'type': 1},
#  {'piece': '▁looked', 'id': 292, 'score': -8.181940078735352, 'type': 1},
#  {'piece': '▁line', 'id': 293, 'score': -8.183260917663574, 'type': 1},
#  {'piece': '▁international', 'id': 294, 'score': -8.18810749053955, 'type': 1},
#  {'piece': '▁june', 'id': 295, 'score': -8.188834190368652, 'type': 1},
#  {'piece': '▁went', 'id': 296, 'score': -8.189620018005371, 'type': 1},
#  {'piece': '▁general', 'id': 297, 'score': -8.190140724182129, 'type': 1},
#  {'piece': '▁show', 'id': 298, 'score': -8.193553924560547, 'type': 1},
#  {'piece': '▁september', 'id': 299, 'score': -8.195722579956055, 'type': 1},
#  {'piece': '4', 'id': 300, 'score': -8.19871711730957, 'type': 1},
#  {'piece': '▁something', 'id': 301, 'score': -8.200203895568848, 'type': 1},
#  {'piece': '▁re', 'id': 302, 'score': -8.201743125915527, 'type': 1},
#  {'piece': '▁along', 'id': 303, 'score': -8.20314884185791, 'type': 1},
#  {'piece': '▁men', 'id': 304, 'score': -8.204660415649414, 'type': 1},
#  {'piece': '▁york', 'id': 305, 'score': -8.205430030822754, 'type': 1},
#  {'piece': 'p', 'id': 306, 'score': -8.207351684570312, 'type': 1},
#  {'piece': '▁m', 'id': 307, 'score': -8.212148666381836, 'type': 1},
#  {'piece': '▁water', 'id': 308, 'score': -8.214953422546387, 'type': 1},
#  {'piece': '▁set', 'id': 309, 'score': -8.215051651000977, 'type': 1},
#  {'piece': '▁few', 'id': 310, 'score': -8.215532302856445, 'type': 1},
#  {'piece': '▁october', 'id': 311, 'score': -8.215869903564453, 'type': 1},
#  {'piece': '▁station', 'id': 312, 'score': -8.219521522521973, 'type': 1},
#  {'piece': '▁july', 'id': 313, 'score': -8.223888397216797, 'type': 1},
#  {'piece': '▁college', 'id': 314, 'score': -8.22475814819336, 'type': 1},
#  {'piece': '▁old', 'id': 315, 'score': -8.22537612915039, 'type': 1},
#  {'piece': '▁august', 'id': 316, 'score': -8.226377487182617, 'type': 1},
#  {'piece': '▁public', 'id': 317, 'score': -8.22641658782959, 'type': 1},
#  {'piece': '▁our', 'id': 318, 'score': -8.228341102600098, 'type': 1},
#  {'piece': '▁black', 'id': 319, 'score': -8.230767250061035, 'type': 1},
#  {'piece': '▁january', 'id': 320, 'score': -8.234314918518066, 'type': 1},
#  {'piece': '▁father', 'id': 321, 'score': -8.239179611206055, 'type': 1},
#  {'piece': '▁member', 'id': 322, 'score': -8.245184898376465, 'type': 1},
#  {'piece': '▁band', 'id': 323, 'score': -8.246391296386719, 'type': 1},
#  {'piece': '▁church', 'id': 324, 'score': -8.252679824829102, 'type': 1},
#  {'piece': 'na', 'id': 325, 'score': -8.252970695495605, 'type': 1},
#  {'piece': '▁co', 'id': 326, 'score': -8.255049705505371, 'type': 1},
#  {'piece': '▁april', 'id': 327, 'score': -8.258477210998535, 'type': 1},
#  {'piece': '▁next', 'id': 328, 'score': -8.261497497558594, 'type': 1},
#  {'piece': '▁system', 'id': 329, 'score': -8.261743545532227, 'type': 1},
#  {'piece': '▁got', 'id': 330, 'score': -8.262879371643066, 'type': 1},
#  {'piece': '▁5', 'id': 331, 'score': -8.266412734985352, 'type': 1},
#  {'piece': '▁10', 'id': 332, 'score': -8.270334243774414, 'type': 1},
#  {'piece': '▁la', 'id': 333, 'score': -8.271142959594727, 'type': 1},
#  {'piece': '▁b', 'id': 334, 'score': -8.272035598754883, 'type': 1},
#  {'piece': '▁located', 'id': 335, 'score': -8.27518081665039, 'type': 1},
#  {'piece': '▁former', 'id': 336, 'score': -8.277983665466309, 'type': 1},
#  {'piece': '▁room', 'id': 337, 'score': -8.279022216796875, 'type': 1},
#  {'piece': '▁song', 'id': 338, 'score': -8.280941009521484, 'type': 1},
#  {'piece': '▁love', 'id': 339, 'score': -8.281988143920898, 'type': 1},
#  {'piece': '▁come', 'id': 340, 'score': -8.282648086547852, 'type': 1},
#  {'piece': '▁river', 'id': 341, 'score': -8.284767150878906, 'type': 1},
#  {'piece': '▁east', 'id': 342, 'score': -8.290175437927246, 'type': 1},
#  {'piece': '▁night', 'id': 343, 'score': -8.293437957763672, 'type': 1},
#  {'piece': '▁november', 'id': 344, 'score': -8.294631958007812, 'type': 1},
#  {'piece': '▁single', 'id': 345, 'score': -8.29680061340332, 'type': 1},
#  {'piece': '▁party', 'id': 346, 'score': -8.2979736328125, 'type': 1},
#  {'piece': '▁16', 'id': 347, 'score': -8.299694061279297, 'type': 1},
#  {'piece': '▁age', 'id': 348, 'score': -8.303755760192871, 'type': 1},
#  {'piece': '▁car', 'id': 349, 'score': -8.306004524230957, 'type': 1},
#  {'piece': '▁population', 'id': 350, 'score': -8.32010269165039, 'type': 1},
#  {'piece': '▁p', 'id': 351, 'score': -8.32082462310791, 'type': 1},
#  {'piece': '▁every', 'id': 352, 'score': -8.32189655303955, 'type': 1},
#  {'piece': '▁building', 'id': 353, 'score': -8.322057723999023, 'type': 1},
#  {'piece': '▁st', 'id': 354, 'score': -8.323429107666016, 'type': 1},
#  {'piece': '▁five', 'id': 355, 'score': -8.32458782196045, 'type': 1},
#  {'piece': '▁december', 'id': 356, 'score': -8.325278282165527, 'type': 1},
#  {'piece': '▁15', 'id': 357, 'score': -8.327468872070312, 'type': 1},
#  {'piece': '▁body', 'id': 358, 'score': -8.328025817871094, 'type': 1},
#  {'piece': '▁white', 'id': 359, 'score': -8.330123901367188, 'type': 1},
#  {'piece': '▁book', 'id': 360, 'score': -8.335516929626465, 'type': 1},
#  {'piece': '▁look', 'id': 361, 'score': -8.3358736038208, 'type': 1},
#  {'piece': '▁though', 'id': 362, 'score': -8.337506294250488, 'type': 1},
#  {'piece': '▁within', 'id': 363, 'score': -8.339908599853516, 'type': 1},
#  {'piece': '▁women', 'id': 364, 'score': -8.340673446655273, 'type': 1},
#  {'piece': '▁service', 'id': 365, 'score': -8.341471672058105, 'type': 1},
#  {'piece': '▁without', 'id': 366, 'score': -8.342266082763672, 'type': 1},
#  {'piece': '▁un', 'id': 367, 'score': -8.34449577331543, 'type': 1},
#  {'piece': '▁open', 'id': 368, 'score': -8.347933769226074, 'type': 1},
#  {'piece': '▁17', 'id': 369, 'score': -8.350102424621582, 'type': 1},
#  {'piece': '▁large', 'id': 370, 'score': -8.350228309631348, 'type': 1},
#  {'piece': '▁top', 'id': 371, 'score': -8.350826263427734, 'type': 1},
#  {'piece': '▁death', 'id': 372, 'score': -8.35228443145752, 'type': 1},
#  {'piece': '▁started', 'id': 373, 'score': -8.352805137634277, 'type': 1},
#  {'piece': '▁great', 'id': 374, 'score': -8.35562515258789, 'type': 1},
#  {'piece': '▁local', 'id': 375, 'score': -8.357288360595703, 'type': 1},
#  {'piece': '▁need', 'id': 376, 'score': -8.36309814453125, 'type': 1},
#  {'piece': '▁named', 'id': 377, 'score': -8.363198280334473, 'type': 1},
#  {'piece': '▁should', 'id': 378, 'score': -8.365439414978027, 'type': 1},
#  {'piece': '6', 'id': 379, 'score': -8.367918014526367, 'type': 1},
#  {'piece': 'z', 'id': 380, 'score': -8.371020317077637, 'type': 1},
#  {'piece': 'born', 'id': 381, 'score': -8.376349449157715, 'type': 1},
#  {'piece': '▁once', 'id': 382, 'score': -8.377436637878418, 'type': 1},
#  {'piece': '▁road', 'id': 383, 'score': -8.38039779663086, 'type': 1},
#  {'piece': 'st', 'id': 384, 'score': -8.380558967590332, 'type': 1},
#  {'piece': '▁moved', 'id': 385, 'score': -8.380585670471191, 'type': 1},
#  {'piece': '▁born', 'id': 386, 'score': -8.385114669799805, 'type': 1},
#  {'piece': '0', 'id': 387, 'score': -8.385414123535156, 'type': 1},
#  {'piece': '▁british', 'id': 388, 'score': -8.388047218322754, 'type': 1},
#  {'piece': '▁order', 'id': 389, 'score': -8.389128684997559, 'type': 1},
#  {'piece': '▁12', 'id': 390, 'score': -8.391207695007324, 'type': 1},
#  {'piece': '▁children', 'id': 391, 'score': -8.392117500305176, 'type': 1},
#  {'piece': '▁built', 'id': 392, 'score': -8.394219398498535, 'type': 1},
#  {'piece': '▁door', 'id': 393, 'score': -8.396249771118164, 'type': 1},
#  {'piece': '▁major', 'id': 394, 'score': -8.398782730102539, 'type': 1},
#  {'piece': '▁say', 'id': 395, 'score': -8.399205207824707, 'type': 1},
#  {'piece': 'x', 'id': 396, 'score': -8.399280548095703, 'type': 1},
#  {'piece': '▁due', 'id': 397, 'score': -8.399333953857422, 'type': 1},
#  {'piece': '▁f', 'id': 398, 'score': -8.399958610534668, 'type': 1},
#  {'piece': '▁village', 'id': 399, 'score': -8.403837203979492, 'type': 1},
#  {'piece': '▁6', 'id': 400, 'score': -8.408251762390137, 'type': 1},
#  {'piece': '▁km', 'id': 401, 'score': -8.415842056274414, 'type': 1},
#  {'piece': '▁red', 'id': 402, 'score': -8.419734954833984, 'type': 1},
#  {'piece': 'is', 'id': 403, 'score': -8.42188549041748, 'type': 1},
#  {'piece': '▁knew', 'id': 404, 'score': -8.422940254211426, 'type': 1},
#  {'piece': '▁park', 'id': 405, 'score': -8.424924850463867, 'type': 1},
#  {'piece': '▁president', 'id': 406, 'score': -8.425436019897461, 'type': 1},
#  {'piece': '▁main', 'id': 407, 'score': -8.427591323852539, 'type': 1},
#  {'piece': '▁let', 'id': 408, 'score': -8.430989265441895, 'type': 1},
#  {'piece': '▁february', 'id': 409, 'score': -8.431873321533203, 'type': 1},
#  {'piece': 'f', 'id': 410, 'score': -8.434237480163574, 'type': 1},
#  {'piece': '▁asked', 'id': 411, 'score': -8.437506675720215, 'type': 1},
#  {'piece': '▁turned', 'id': 412, 'score': -8.438321113586426, 'type': 1},
#  {'piece': 'le', 'id': 413, 'score': -8.439984321594238, 'type': 1},
#  {'piece': '▁power', 'id': 414, 'score': -8.440083503723145, 'type': 1},
#  {'piece': '▁art', 'id': 415, 'score': -8.443367958068848, 'type': 1},
#  {'piece': '▁per', 'id': 416, 'score': -8.444267272949219, 'type': 1},
#  {'piece': '▁wanted', 'id': 417, 'score': -8.447672843933105, 'type': 1},
#  {'piece': '▁play', 'id': 418, 'score': -8.447879791259766, 'type': 1},
#  {'piece': '▁although', 'id': 419, 'score': -8.448538780212402, 'type': 1},
#  {'piece': '▁received', 'id': 420, 'score': -8.451028823852539, 'type': 1},
#  {'piece': '▁different', 'id': 421, 'score': -8.452548027038574, 'type': 1},
#  {'piece': '▁third', 'id': 422, 'score': -8.45272159576416, 'type': 1},
#  {'piece': '▁served', 'id': 423, 'score': -8.455157279968262, 'type': 1},
#  {'piece': '▁near', 'id': 424, 'score': -8.456400871276855, 'type': 1},
#  {'piece': '▁himself', 'id': 425, 'score': -8.459063529968262, 'type': 1},
#  {'piece': '▁final', 'id': 426, 'score': -8.459184646606445, 'type': 1},
#  {'piece': '▁felt', 'id': 427, 'score': -8.462381362915039, 'type': 1},
#  {'piece': '▁century', 'id': 428, 'score': -8.463422775268555, 'type': 1},
#  {'piece': '▁together', 'id': 429, 'score': -8.464356422424316, 'type': 1},
#  {'piece': '▁voice', 'id': 430, 'score': -8.465057373046875, 'type': 1},
#  {'piece': '▁front', 'id': 431, 'score': -8.466654777526855, 'type': 1},
#  {'piece': '▁based', 'id': 432, 'score': -8.468045234680176, 'type': 1},
#  {'piece': '▁son', 'id': 433, 'score': -8.468114852905273, 'type': 1},
#  {'piece': '▁20', 'id': 434, 'score': -8.469943046569824, 'type': 1},
#  {'piece': '▁football', 'id': 435, 'score': -8.473490715026855, 'type': 1},
#  {'piece': '▁times', 'id': 436, 'score': -8.474778175354004, 'type': 1},
#  {'piece': '▁king', 'id': 437, 'score': -8.477025985717773, 'type': 1},
#  {'piece': 'he', 'id': 438, 'score': -8.478616714477539, 'type': 1},
#  {'piece': '▁behind', 'id': 439, 'score': -8.478715896606445, 'type': 1},
#  {'piece': '▁died', 'id': 440, 'score': -8.478899002075195, 'type': 1},
#  {'piece': '▁saw', 'id': 441, 'score': -8.4791841506958, 'type': 1},
#  {'piece': '▁put', 'id': 442, 'score': -8.481780052185059, 'type': 1},
#  {'piece': '▁members', 'id': 443, 'score': -8.484172821044922, 'type': 1},
#  {'piece': 'ton', 'id': 444, 'score': -8.488460540771484, 'type': 1},
#  {'piece': 'ers', 'id': 445, 'score': -8.494876861572266, 'type': 1},
#  {'piece': '▁street', 'id': 446, 'score': -8.496078491210938, 'type': 1},
#  {'piece': '▁history', 'id': 447, 'score': -8.499831199645996, 'type': 1},
#  {'piece': '▁help', 'id': 448, 'score': -8.505134582519531, 'type': 1},
#  {'piece': '▁mother', 'id': 449, 'score': -8.506083488464355, 'type': 1},
#  {'piece': '▁award', 'id': 450, 'score': -8.507308006286621, 'type': 1},
#  {'piece': '▁law', 'id': 451, 'score': -8.51180648803711, 'type': 1},
#  {'piece': '▁having', 'id': 452, 'score': -8.51187801361084, 'type': 1},
#  {'piece': '▁7', 'id': 453, 'score': -8.5121431350708, 'type': 1},
#  {'piece': '▁point', 'id': 454, 'score': -8.516353607177734, 'type': 1},
#  {'piece': '▁army', 'id': 455, 'score': -8.517599105834961, 'type': 1},
#  {'piece': '▁late', 'id': 456, 'score': -8.517784118652344, 'type': 1},
#  {'piece': '8', 'id': 457, 'score': -8.52412223815918, 'type': 1},
#  {'piece': 'we', 'id': 458, 'score': -8.533370971679688, 'type': 1},
#  {'piece': '▁center', 'id': 459, 'score': -8.538676261901855, 'type': 1},
#  {'piece': '▁division', 'id': 460, 'score': -8.540207862854004, 'type': 1},
#  {'piece': '▁young', 'id': 461, 'score': -8.540427207946777, 'type': 1},
#  {'piece': '▁ever', 'id': 462, 'score': -8.546039581298828, 'type': 1},
#  {'piece': '▁far', 'id': 463, 'score': -8.546721458435059, 'type': 1},
#  {'piece': '▁across', 'id': 464, 'score': -8.548821449279785, 'type': 1},
#  {'piece': '7', 'id': 465, 'score': -8.552267074584961, 'type': 1},
#  {'piece': '▁games', 'id': 466, 'score': -8.554461479187012, 'type': 1},
#  {'piece': '▁published', 'id': 467, 'score': -8.556931495666504, 'type': 1},
#  {'piece': '▁include', 'id': 468, 'score': -8.558065414428711, 'type': 1},
#  {'piece': '▁8', 'id': 469, 'score': -8.558859825134277, 'type': 1},
#  {'piece': '▁told', 'id': 470, 'score': -8.558939933776855, 'type': 1},
#  {'piece': '▁light', 'id': 471, 'score': -8.55894947052002, 'type': 1},
#  {'piece': 'as', 'id': 472, 'score': -8.564913749694824, 'type': 1},
#  {'piece': '▁hands', 'id': 473, 'score': -8.565849304199219, 'type': 1},
#  {'piece': '▁18', 'id': 474, 'score': -8.56745433807373, 'type': 1},
#  {'piece': '▁country', 'id': 475, 'score': -8.567933082580566, 'type': 1},
#  {'piece': '▁land', 'id': 476, 'score': -8.56909465789795, 'type': 1},
#  {'piece': '▁find', 'id': 477, 'score': -8.573564529418945, 'type': 1},
#  {'piece': '▁often', 'id': 478, 'score': -8.581117630004883, 'type': 1},
#  {'piece': '▁london', 'id': 479, 'score': -8.582381248474121, 'type': 1},
#  {'piece': '▁cup', 'id': 480, 'score': -8.582423210144043, 'type': 1},
#  {'piece': '▁led', 'id': 481, 'score': -8.583704948425293, 'type': 1},
#  {'piece': '▁species', 'id': 482, 'score': -8.586206436157227, 'type': 1},
#  {'piece': '▁why', 'id': 483, 'score': -8.590433120727539, 'type': 1},
#  {'piece': '▁french', 'id': 484, 'score': -8.591429710388184, 'type': 1},
#  {'piece': '▁run', 'id': 485, 'score': -8.592235565185547, 'type': 1},
#  {'piece': '▁english', 'id': 486, 'score': -8.592630386352539, 'type': 1},
#  {'piece': '▁j', 'id': 487, 'score': -8.592934608459473, 'type': 1},
#  {'piece': '▁office', 'id': 488, 'score': -8.594852447509766, 'type': 1},
#  {'piece': '▁g', 'id': 489, 'score': -8.595057487487793, 'type': 1},
#  {'piece': '▁six', 'id': 490, 'score': -8.595260620117188, 'type': 1},
#  {'piece': '▁must', 'id': 491, 'score': -8.596273422241211, 'type': 1},
#  {'piece': '▁gave', 'id': 492, 'score': -8.59759521484375, 'type': 1},
#  {'piece': '▁al', 'id': 493, 'score': -8.597711563110352, 'type': 1},
#  {'piece': '▁tell', 'id': 494, 'score': -8.59781551361084, 'type': 1},
#  {'piece': '▁court', 'id': 495, 'score': -8.598731994628906, 'type': 1},
#  {'piece': '▁according', 'id': 496, 'score': -8.602556228637695, 'type': 1},
#  {'piece': '▁among', 'id': 497, 'score': -8.604264259338379, 'type': 1},
#  {'piece': '▁2010', 'id': 498, 'score': -8.604398727416992, 'type': 1},
#  {'piece': 'w', 'id': 499, 'score': -8.604840278625488, 'type': 1},
#  {'piece': ']', 'id': 500, 'score': -8.607275009155273, 'type': 1},
#  {'piece': '▁original', 'id': 501, 'score': -8.610212326049805, 'type': 1},
#  {'piece': '▁short', 'id': 502, 'score': -8.61174488067627, 'type': 1},
#  {'piece': '▁full', 'id': 503, 'score': -8.612836837768555, 'type': 1},
#  {'piece': '▁given', 'id': 504, 'score': -8.613716125488281, 'type': 1},
#  {'piece': '▁form', 'id': 505, 'score': -8.614845275878906, 'type': 1},
#  {'piece': '▁included', 'id': 506, 'score': -8.614848136901855, 'type': 1},
#  {'piece': '▁million', 'id': 507, 'score': -8.618183135986328, 'type': 1},
#  {'piece': '▁business', 'id': 508, 'score': -8.619600296020508, 'type': 1},
#  {'piece': '▁days', 'id': 509, 'score': -8.619610786437988, 'type': 1},
#  {'piece': '▁really', 'id': 510, 'score': -8.622142791748047, 'type': 1},
#  {'piece': '▁enough', 'id': 511, 'score': -8.622526168823242, 'type': 1},
#  {'piece': 'ar', 'id': 512, 'score': -8.62736988067627, 'type': 1},
#  {'piece': '▁14', 'id': 513, 'score': -8.629724502563477, 'type': 1},
#  {'piece': '▁community', 'id': 514, 'score': -8.63078784942627, 'type': 1},
#  {'piece': '▁live', 'id': 515, 'score': -8.632044792175293, 'type': 1},
#  {'piece': '▁council', 'id': 516, 'score': -8.633936882019043, 'type': 1},
#  {'piece': '▁player', 'id': 517, 'score': -8.634298324584961, 'type': 1},
#  {'piece': '9', 'id': 518, 'score': -8.63620662689209, 'type': 1},
#  {'piece': '▁half', 'id': 519, 'score': -8.63664436340332, 'type': 1},
#  {'piece': '▁opened', 'id': 520, 'score': -8.636808395385742, 'type': 1},
#  {'piece': '▁central', 'id': 521, 'score': -8.637758255004883, 'type': 1},
#  {'piece': '▁development', 'id': 522, 'score': -8.641353607177734, 'type': 1},
#  {'piece': '▁san', 'id': 523, 'score': -8.6417236328125, 'type': 1},
#  {'piece': '▁woman', 'id': 524, 'score': -8.642465591430664, 'type': 1},
#  {'piece': 'ra', 'id': 525, 'score': -8.645124435424805, 'type': 1},
#  {'piece': '▁wasn', 'id': 526, 'score': -8.64549732208252, 'type': 1},
#  {'piece': '▁research', 'id': 527, 'score': -8.64602279663086, 'type': 1},
#  {'piece': 'son', 'id': 528, 'score': -8.646586418151855, 'type': 1},
#  {'piece': '▁lost', 'id': 529, 'score': -8.647625923156738, 'type': 1},
#  {'piece': '▁might', 'id': 530, 'score': -8.64831829071045, 'type': 1},
#  {'piece': 'la', 'id': 531, 'score': -8.648797988891602, 'type': 1},
#  {'piece': 'el', 'id': 532, 'score': -8.655545234680176, 'type': 1},
#  {'piece': '▁become', 'id': 533, 'score': -8.65585994720459, 'type': 1},
#  {'piece': '▁mi', 'id': 534, 'score': -8.659459114074707, 'type': 1},
#  {'piece': '▁fire', 'id': 535, 'score': -8.661186218261719, 'type': 1},
#  {'piece': 'ta', 'id': 536, 'score': -8.661275863647461, 'type': 1},
#  {'piece': 'do', 'id': 537, 'score': -8.663376808166504, 'type': 1},
#  {'piece': '▁non', 'id': 538, 'score': -8.667330741882324, 'type': 1},
#  {'piece': '▁13', 'id': 539, 'score': -8.672054290771484, 'type': 1},
#  {'piece': 'ma', 'id': 540, 'score': -8.675942420959473, 'type': 1},
#  {'piece': '▁seen', 'id': 541, 'score': -8.677619934082031, 'type': 1},
#  {'piece': '▁2011', 'id': 542, 'score': -8.67819595336914, 'type': 1},
#  {'piece': '▁close', 'id': 543, 'score': -8.67966079711914, 'type': 1},
#  {'piece': '▁making', 'id': 544, 'score': -8.679689407348633, 'type': 1},
#  {'piece': '▁career', 'id': 545, 'score': -8.680638313293457, 'type': 1},
#  {'piece': 'de', 'id': 546, 'score': -8.681577682495117, 'type': 1},
#  {'piece': '▁11', 'id': 547, 'score': -8.683260917663574, 'type': 1},
#  {'piece': '▁german', 'id': 548, 'score': -8.683690071105957, 'type': 1},
#  {'piece': 'ia', 'id': 549, 'score': -8.684194564819336, 'type': 1},
#  {'piece': '▁always', 'id': 550, 'score': -8.688501358032227, 'type': 1},
#  {'piece': '▁free', 'id': 551, 'score': -8.696115493774414, 'type': 1},
#  {'piece': '▁hard', 'id': 552, 'score': -8.697198867797852, 'type': 1},
#  {'piece': '▁island', 'id': 553, 'score': -8.702413558959961, 'type': 1},
#  {'piece': '▁hall', 'id': 554, 'score': -8.706491470336914, 'type': 1},
#  {'piece': '▁support', 'id': 555, 'score': -8.70748233795166, 'type': 1},
#  {'piece': 'ne', 'id': 556, 'score': -8.708707809448242, 'type': 1},
#  {'piece': '▁almost', 'id': 557, 'score': -8.709355354309082, 'type': 1},
#  {'piece': '▁force', 'id': 558, 'score': -8.71122932434082, 'type': 1},
#  {'piece': '▁director', 'id': 559, 'score': -8.712173461914062, 'type': 1},
#  {'piece': '▁round', 'id': 560, 'score': -8.713759422302246, 'type': 1},
#  {'piece': '▁9', 'id': 561, 'score': -8.716047286987305, 'type': 1},
#  {'piece': '▁sure', 'id': 562, 'score': -8.718873023986816, 'type': 1},
#  {'piece': '▁2012', 'id': 563, 'score': -8.724858283996582, 'type': 1},
#  {'piece': '▁things', 'id': 564, 'score': -8.724954605102539, 'type': 1},
#  {'piece': '▁education', 'id': 565, 'score': -8.725512504577637, 'type': 1},
#  {'piece': '▁v', 'id': 566, 'score': -8.729570388793945, 'type': 1},
#  {'piece': '▁married', 'id': 567, 'score': -8.73048210144043, 'type': 1},
#  {'piece': '▁using', 'id': 568, 'score': -8.731484413146973, 'type': 1},
#  {'piece': '▁control', 'id': 569, 'score': -8.735291481018066, 'type': 1},
#  {'piece': '▁2008', 'id': 570, 'score': -8.735888481140137, 'type': 1},
#  {'piece': '▁record', 'id': 571, 'score': -8.735980033874512, 'type': 1},
#  {'piece': '▁inside', 'id': 572, 'score': -8.739017486572266, 'type': 1},
#  {'piece': '▁students', 'id': 573, 'score': -8.740435600280762, 'type': 1},
#  {'piece': '▁better', 'id': 574, 'score': -8.744134902954102, 'type': 1},
#  {'piece': '▁field', 'id': 575, 'score': -8.745017051696777, 'type': 1},
#  {'piece': 'up', 'id': 576, 'score': -8.746373176574707, 'type': 1},
#  {'piece': '▁worked', 'id': 577, 'score': -8.746598243713379, 'type': 1},
#  {'piece': '▁continued', 'id': 578, 'score': -8.746947288513184, 'type': 1},
#  {'piece': 'able', 'id': 579, 'score': -8.749966621398926, 'type': 1},
#  {'piece': '▁big', 'id': 580, 'score': -8.751090049743652, 'type': 1},
#  {'piece': '▁title', 'id': 581, 'score': -8.751496315002441, 'type': 1},
#  {'piece': '▁heart', 'id': 582, 'score': -8.751721382141113, 'type': 1},
#  {'piece': '▁feel', 'id': 583, 'score': -8.752769470214844, 'type': 1},
#  {'piece': '▁thing', 'id': 584, 'score': -8.75355339050293, 'type': 1},
#  {'piece': '▁human', 'id': 585, 'score': -8.754606246948242, 'type': 1},
#  {'piece': '▁james', 'id': 586, 'score': -8.755115509033203, 'type': 1},
#  {'piece': '▁returned', 'id': 587, 'score': -8.759857177734375, 'type': 1},
#  {'piece': '▁2009', 'id': 588, 'score': -8.761053085327148, 'type': 1},
#  {'piece': '▁am', 'id': 589, 'score': -8.76251220703125, 'type': 1},
#  {'piece': '▁give', 'id': 590, 'score': -8.762911796569824, 'type': 1},
#  {'piece': 'te', 'id': 591, 'score': -8.76623249053955, 'type': 1},
#  {'piece': '▁2006', 'id': 592, 'score': -8.766897201538086, 'type': 1},
#  {'piece': 'da', 'id': 593, 'score': -8.767974853515625, 'type': 1},
#  {'piece': '▁mind', 'id': 594, 'score': -8.770456314086914, 'type': 1},
#  {'piece': '▁ii', 'id': 595, 'score': -8.770668029785156, 'type': 1},
#  {'piece': 'ic', 'id': 596, 'score': -8.772252082824707, 'type': 1},
#  {'piece': '▁role', 'id': 597, 'score': -8.77272891998291, 'type': 1},
#  {'piece': '▁sea', 'id': 598, 'score': -8.7731351852417, 'type': 1},
#  {'piece': '▁championship', 'id': 599, 'score': -8.774002075195312, 'type': 1},
#  {'piece': '▁total', 'id': 600, 'score': -8.774088859558105, 'type': 1},
#  {'piece': '▁act', 'id': 601, 'score': -8.774813652038574, 'type': 1},
#  {'piece': '▁anything', 'id': 602, 'score': -8.775100708007812, 'type': 1},
#  {'piece': '▁radio', 'id': 603, 'score': -8.776152610778809, 'type': 1},
#  {'piece': '▁department', 'id': 604, 'score': -8.77629280090332, 'type': 1},
#  {'piece': '▁william', 'id': 605, 'score': -8.779823303222656, 'type': 1},
#  {'piece': '▁feet', 'id': 606, 'score': -8.783672332763672, 'type': 1},
#  {'piece': '▁association', 'id': 607, 'score': -8.784273147583008, 'type': 1},
#  {'piece': 'what', 'id': 608, 'score': -8.784326553344727, 'type': 1},
#  {'piece': '▁story', 'id': 609, 'score': -8.78447437286377, 'type': 1},
#  {'piece': '▁case', 'id': 610, 'score': -8.790557861328125, 'type': 1},
#  {'piece': '▁military', 'id': 611, 'score': -8.7921781539917, 'type': 1},
#  {'piece': '▁royal', 'id': 612, 'score': -8.79301643371582, 'type': 1},
#  {'piece': '▁established', 'id': 613, 'score': -8.794055938720703, 'type': 1},
#  {'piece': '▁already', 'id': 614, 'score': -8.796144485473633, 'type': 1},
#  {'piece': '▁version', 'id': 615, 'score': -8.796265602111816, 'type': 1},
#  {'piece': '▁2013', 'id': 616, 'score': -8.796280860900879, 'type': 1},
#  {'piece': '▁various', 'id': 617, 'score': -8.797797203063965, 'type': 1},
#  {'piece': 'land', 'id': 618, 'score': -8.798866271972656, 'type': 1},
#  {'piece': '▁w', 'id': 619, 'score': -8.799053192138672, 'type': 1},
#  {'piece': '▁period', 'id': 620, 'score': -8.80151653289795, 'type': 1},
#  {'piece': '▁special', 'id': 621, 'score': -8.803199768066406, 'type': 1},
#  {'piece': 'ry', 'id': 622, 'score': -8.804892539978027, 'type': 1},
#  {'piece': '▁2014', 'id': 623, 'score': -8.805007934570312, 'type': 1},
#  {'piece': '▁2007', 'id': 624, 'score': -8.806364059448242, 'type': 1},
#  {'piece': '▁program', 'id': 625, 'score': -8.806775093078613, 'type': 1},
#  {'piece': '▁nothing', 'id': 626, 'score': -8.810125350952148, 'type': 1},
#  {'piece': '▁hair', 'id': 627, 'score': -8.812626838684082, 'type': 1},
#  {'piece': '▁win', 'id': 628, 'score': -8.81356143951416, 'type': 1},
#  {'piece': '▁rock', 'id': 629, 'score': -8.81363296508789, 'type': 1},
#  {'piece': '▁does', 'id': 630, 'score': -8.813726425170898, 'type': 1},
#  {'piece': 'ley', 'id': 631, 'score': -8.814526557922363, 'type': 1},
#  {'piece': '▁region', 'id': 632, 'score': -8.816088676452637, 'type': 1},
#  {'piece': '▁television', 'id': 633, 'score': -8.816605567932129, 'type': 1},
#  {'piece': '▁living', 'id': 634, 'score': -8.817617416381836, 'type': 1},
#  {'piece': '▁o', 'id': 635, 'score': -8.817972183227539, 'type': 1},
#  {'piece': '▁[', 'id': 636, 'score': -8.819143295288086, 'type': 1},
#  {'piece': '▁production', 'id': 637, 'score': -8.820294380187988, 'type': 1},
#  {'piece': '▁working', 'id': 638, 'score': -8.821207046508789, 'type': 1},
#  {'piece': '▁least', 'id': 639, 'score': -8.823650360107422, 'type': 1},
#  {'piece': '▁past', 'id': 640, 'score': -8.825407981872559, 'type': 1},
#  {'piece': '▁society', 'id': 641, 'score': -8.832589149475098, 'type': 1},
#  {'piece': '▁written', 'id': 642, 'score': -8.832764625549316, 'type': 1},
#  {'piece': '▁keep', 'id': 643, 'score': -8.83724308013916, 'type': 1},
#  {'piece': '▁l', 'id': 644, 'score': -8.840749740600586, 'type': 1},
#  {'piece': '▁call', 'id': 645, 'score': -8.84346866607666, 'type': 1},
#  {'piece': '▁sound', 'id': 646, 'score': -8.844998359680176, 'type': 1},
#  {'piece': '▁green', 'id': 647, 'score': -8.846250534057617, 'type': 1},
#  {'piece': '▁england', 'id': 648, 'score': -8.846543312072754, 'type': 1},
#  {'piece': '▁position', 'id': 649, 'score': -8.84753131866455, 'type': 1},
#  {'piece': '▁western', 'id': 650, 'score': -8.84950065612793, 'type': 1},
#  {'piece': '▁soon', 'id': 651, 'score': -8.850210189819336, 'type': 1},
#  {'piece': '▁ten', 'id': 652, 'score': -8.850265502929688, 'type': 1},
#  {'piece': '▁further', 'id': 653, 'score': -8.851639747619629, 'type': 1},
#  {'piece': '▁others', 'id': 654, 'score': -8.852210998535156, 'type': 1},
#  {'piece': '▁brother', 'id': 655, 'score': -8.852365493774414, 'type': 1},
#  {'piece': 'so', 'id': 656, 'score': -8.855056762695312, 'type': 1},
#  {'piece': 'ka', 'id': 657, 'score': -8.855557441711426, 'type': 1},
#  {'piece': '▁taken', 'id': 658, 'score': -8.856578826904297, 'type': 1},
#  {'piece': '▁dark', 'id': 659, 'score': -8.85733413696289, 'type': 1},
#  {'piece': 'ie', 'id': 660, 'score': -8.858810424804688, 'type': 1},
#  {'piece': 'ro', 'id': 661, 'score': -8.859307289123535, 'type': 1},
#  {'piece': '▁level', 'id': 662, 'score': -8.859747886657715, 'type': 1},
#  {'piece': '▁wife', 'id': 663, 'score': -8.86316204071045, 'type': 1},
#  {'piece': '▁reached', 'id': 664, 'score': -8.8635835647583, 'type': 1},
#  {'piece': '▁george', 'id': 665, 'score': -8.863950729370117, 'type': 1},
#  {'piece': '▁ground', 'id': 666, 'score': -8.864757537841797, 'type': 1},
#  {'piece': '▁union', 'id': 667, 'score': -8.865036964416504, 'type': 1},
#  {'piece': '▁social', 'id': 668, 'score': -8.866170883178711, 'type': 1},
#  {'piece': '▁project', 'id': 669, 'score': -8.868023872375488, 'type': 1},
#  {'piece': '▁joined', 'id': 670, 'score': -8.869455337524414, 'type': 1},
# ...
#  {'piece': '▁care', 'id': 781, 'score': -9.004881858825684, 'type': 1},
#  {'piece': '▁pre', 'id': 782, 'score': -9.005230903625488, 'type': 1},
#  {'piece': '▁daughter', 'id': 783, 'score': -9.005739212036133, 'type': 1},
#  {'piece': '▁above', 'id': 784, 'score': -9.008880615234375, 'type': 1},
#  {'piece': '▁founded', 'id': 785, 'score': -9.012054443359375, 'type': 1},
#  {'piece': '▁today', 'id': 786, 'score': -9.015037536621094, 'type': 1},
#  {'piece': '▁less', 'id': 787, 'score': -9.015389442443848, 'type': 1},
#  {'piece': '▁return', 'id': 788, 'score': -9.015792846679688, 'type': 1},
#  {'piece': '▁minister', 'id': 789, 'score': -9.01789665222168, 'type': 1},
#  {'piece': 'me', 'id': 790, 'score': -9.018973350524902, 'type': 1},
#  {'piece': '▁playing', 'id': 791, 'score': -9.022035598754883, 'type': 1},
#  {'piece': '▁track', 'id': 792, 'score': -9.025055885314941, 'type': 1},
#  {'piece': 'ca', 'id': 793, 'score': -9.026698112487793, 'type': 1},
#  {'piece': '▁tried', 'id': 794, 'score': -9.026984214782715, 'type': 1},
#  {'piece': '▁sent', 'id': 795, 'score': -9.02722454071045, 'type': 1},
#  {'piece': '▁everything', 'id': 796, 'score': -9.027956008911133, 'type': 1},
#  {'piece': '▁im', 'id': 797, 'score': -9.028733253479004, 'type': 1},
#  {'piece': '▁met', 'id': 798, 'score': -9.028924942016602, 'type': 1},
#  {'piece': '▁start', 'id': 799, 'score': -9.029155731201172, 'type': 1},
#  {'piece': '▁=', 'id': 800, 'score': -9.030476570129395, 'type': 1},
#  {'piece': '▁recorded', 'id': 801, 'score': -9.031928062438965, 'type': 1},
#  {'piece': 'ling', 'id': 802, 'score': -9.033535957336426, 'type': 1},
#  {'piece': '▁floor', 'id': 803, 'score': -9.034985542297363, 'type': 1},
#  {'piece': 'don', 'id': 804, 'score': -9.038530349731445, 'type': 1},
#  {'piece': '▁turn', 'id': 805, 'score': -9.038778305053711, 'type': 1},
#  {'piece': 'ian', 'id': 806, 'score': -9.039530754089355, 'type': 1},
#  {'piece': '▁event', 'id': 807, 'score': -9.041131973266602, 'type': 1},
#  {'piece': '▁100', 'id': 808, 'score': -9.042400360107422, 'type': 1},
#  {'piece': '▁brought', 'id': 809, 'score': -9.042586326599121, 'type': 1},
#  {'piece': '▁seven', 'id': 810, 'score': -9.042954444885254, 'type': 1},
#  {'piece': 'but', 'id': 811, 'score': -9.04307746887207, 'type': 1},
#  {'piece': '▁2005', 'id': 812, 'score': -9.044720649719238, 'type': 1},
#  {'piece': '▁arm', 'id': 813, 'score': -9.050043106079102, 'type': 1},
#  {'piece': '▁2017', 'id': 814, 'score': -9.051071166992188, 'type': 1},
#  {'piece': 'ter', 'id': 815, 'score': -9.052620887756348, 'type': 1},
#  {'piece': '▁language', 'id': 816, 'score': -9.054242134094238, 'type': 1},
#  {'piece': 'den', 'id': 817, 'score': -9.054286003112793, 'type': 1},
#  {'piece': '▁months', 'id': 818, 'score': -9.055071830749512, 'type': 1},
#  {'piece': '▁points', 'id': 819, 'score': -9.05531120300293, 'type': 1},
#  {'piece': '▁mr', 'id': 820, 'score': -9.055996894836426, 'type': 1},
#  {'piece': 'if', 'id': 821, 'score': -9.056785583496094, 'type': 1},
#  {'piece': '▁robert', 'id': 822, 'score': -9.057313919067383, 'type': 1},
#  {'piece': '▁example', 'id': 823, 'score': -9.05815601348877, 'type': 1},
#  {'piece': '▁2000', 'id': 824, 'score': -9.059035301208496, 'type': 1},
#  {'piece': '▁kind', 'id': 825, 'score': -9.059161186218262, 'type': 1},
#  {'piece': '▁railway', 'id': 826, 'score': -9.059805870056152, 'type': 1},
#  {'piece': '▁closed', 'id': 827, 'score': -9.061484336853027, 'type': 1},
#  {'piece': '▁dead', 'id': 828, 'score': -9.06492805480957, 'type': 1},
#  {'piece': '▁result', 'id': 829, 'score': -9.066853523254395, 'type': 1},
#  {'piece': '▁release', 'id': 830, 'score': -9.06804084777832, 'type': 1},
#  {'piece': '▁thomas', 'id': 831, 'score': -9.06900691986084, 'type': 1},
#  {'piece': '▁michael', 'id': 832, 'score': -9.069233894348145, 'type': 1},
#  {'piece': '▁word', 'id': 833, 'score': -9.069745063781738, 'type': 1},
#  {'piece': 'ge', 'id': 834, 'score': -9.069860458374023, 'type': 1},
#  {'piece': '▁similar', 'id': 835, 'score': -9.070612907409668, 'type': 1},
#  {'piece': '▁canada', 'id': 836, 'score': -9.070765495300293, 'type': 1},
#  {'piece': '▁fact', 'id': 837, 'score': -9.071380615234375, 'type': 1},
#  {'piece': '▁training', 'id': 838, 'score': -9.073636054992676, 'type': 1},
#  {'piece': 'go', 'id': 839, 'score': -9.075303077697754, 'type': 1},
#  {'piece': '▁person', 'id': 840, 'score': -9.0761079788208, 'type': 1},
#  {'piece': '▁killed', 'id': 841, 'score': -9.077702522277832, 'type': 1},
#  {'piece': '▁finished', 'id': 842, 'score': -9.077795028686523, 'type': 1},
#  {'piece': '▁formed', 'id': 843, 'score': -9.07926082611084, 'type': 1},
#  {'piece': '▁popular', 'id': 844, 'score': -9.07962703704834, 'type': 1},
#  {'piece': '▁doing', 'id': 845, 'score': -9.080572128295898, 'type': 1},
#  {'piece': '▁tour', 'id': 846, 'score': -9.080989837646484, 'type': 1},
#  {'piece': '▁sat', 'id': 847, 'score': -9.081903457641602, 'type': 1},
#  {'piece': '▁addition', 'id': 848, 'score': -9.082040786743164, 'type': 1},
#  {'piece': 'one', 'id': 849, 'score': -9.082942962646484, 'type': 1},
#  {'piece': '▁child', 'id': 850, 'score': -9.085529327392578, 'type': 1},
#  {'piece': '▁needed', 'id': 851, 'score': -9.089699745178223, 'type': 1},
#  {'piece': '▁21', 'id': 852, 'score': -9.089797019958496, 'type': 1},
#  {'piece': '▁health', 'id': 853, 'score': -9.090782165527344, 'type': 1},
#  {'piece': 'well', 'id': 854, 'score': -9.091141700744629, 'type': 1},
#  {'piece': '▁deep', 'id': 855, 'score': -9.093392372131348, 'type': 1},
#  {'piece': 'ity', 'id': 856, 'score': -9.094741821289062, 'type': 1},
#  {'piece': 'ation', 'id': 857, 'score': -9.094858169555664, 'type': 1},
#  {'piece': '▁route', 'id': 858, 'score': -9.095787048339844, 'type': 1},
#  {'piece': '▁table', 'id': 859, 'score': -9.096686363220215, 'type': 1},
#  {'piece': '▁friend', 'id': 860, 'score': -9.097658157348633, 'type': 1},
#  {'piece': '▁centre', 'id': 861, 'score': -9.09969425201416, 'type': 1},
#  {'piece': '▁average', 'id': 862, 'score': -9.100062370300293, 'type': 1},
#  {'piece': 'be', 'id': 863, 'score': -9.101666450500488, 'type': 1},
#  {'piece': '▁rather', 'id': 864, 'score': -9.101744651794434, 'type': 1},
#  {'piece': '▁lot', 'id': 865, 'score': -9.103250503540039, 'type': 1},
#  {'piece': '▁current', 'id': 866, 'score': -9.104284286499023, 'type': 1},
#  {'piece': '▁stood', 'id': 867, 'score': -9.1043701171875, 'type': 1},
#  {'piece': '▁decided', 'id': 868, 'score': -9.10633659362793, 'type': 1},
#  {'piece': '▁despite', 'id': 869, 'score': -9.107407569885254, 'type': 1},
#  {'piece': 'se', 'id': 870, 'score': -9.107871055603027, 'type': 1},
#  {'piece': '▁currently', 'id': 871, 'score': -9.108075141906738, 'type': 1},
#  {'piece': 'ion', 'id': 872, 'score': -9.108244895935059, 'type': 1},
#  {'piece': '▁bed', 'id': 873, 'score': -9.108613967895508, 'type': 1},
#  {'piece': '▁festival', 'id': 874, 'score': -9.110971450805664, 'type': 1},
#  {'piece': '▁money', 'id': 875, 'score': -9.11301326751709, 'type': 1},
#  {'piece': '▁stage', 'id': 876, 'score': -9.11520767211914, 'type': 1},
#  {'piece': '▁week', 'id': 877, 'score': -9.116111755371094, 'type': 1},
#  {'piece': '▁eventually', 'id': 878, 'score': -9.11796760559082, 'type': 1},
#  {'piece': '▁forces', 'id': 879, 'score': -9.120231628417969, 'type': 1},
#  {'piece': '▁coming', 'id': 880, 'score': -9.12049674987793, 'type': 1},
#  {'piece': '▁pulled', 'id': 881, 'score': -9.120645523071289, 'type': 1},
#  {'piece': '▁idea', 'id': 882, 'score': -9.122841835021973, 'type': 1},
#  {'piece': '▁boy', 'id': 883, 'score': -9.123429298400879, 'type': 1},
#  {'piece': '▁mean', 'id': 884, 'score': -9.123924255371094, 'type': 1},
#  {'piece': '▁developed', 'id': 885, 'score': -9.123963356018066, 'type': 1},
#  {'piece': '▁brown', 'id': 886, 'score': -9.124611854553223, 'type': 1},
#  {'piece': 'that', 'id': 887, 'score': -9.12703800201416, 'type': 1},
#  {'piece': '▁elected', 'id': 888, 'score': -9.12718391418457, 'type': 1},
#  {'piece': 'ni', 'id': 889, 'score': -9.127968788146973, 'type': 1},
#  {'piece': '▁seemed', 'id': 890, 'score': -9.128260612487793, 'type': 1},
#  {'piece': 'time', 'id': 891, 'score': -9.13064193725586, 'type': 1},
#  {'piece': '▁throughout', 'id': 892, 'score': -9.130797386169434, 'type': 1},
#  {'piece': '▁debut', 'id': 893, 'score': -9.130884170532227, 'type': 1},
#  {'piece': '▁2004', 'id': 894, 'score': -9.131390571594238, 'type': 1},
#  {'piece': '▁pro', 'id': 895, 'score': -9.132226943969727, 'type': 1},
#  {'piece': '▁bad', 'id': 896, 'score': -9.132383346557617, 'type': 1},
#  {'piece': 'rd', 'id': 897, 'score': -9.136835098266602, 'type': 1},
#  {'piece': '▁says', 'id': 898, 'score': -9.137064933776855, 'type': 1},
#  {'piece': '▁bay', 'id': 899, 'score': -9.138383865356445, 'type': 1},
#  {'piece': '▁construction', 'id': 900, 'score': -9.139025688171387, 'type': 1},
#  {'piece': '▁press', 'id': 901, 'score': -9.139178276062012, 'type': 1},
#  {'piece': '▁minutes', 'id': 902, 'score': -9.141820907592773, 'type': 1},
#  {'piece': '▁chief', 'id': 903, 'score': -9.144026756286621, 'type': 1},
#  {'piece': '▁available', 'id': 904, 'score': -9.14447021484375, 'type': 1},
#  {'piece': '▁added', 'id': 905, 'score': -9.144713401794434, 'type': 1},
#  {'piece': '▁1,', 'id': 906, 'score': -9.145084381103516, 'type': 1},
#  {'piece': '▁mid', 'id': 907, 'score': -9.145511627197266, 'type': 1},
#  {'piece': '▁signed', 'id': 908, 'score': -9.146679878234863, 'type': 1},
#  {'piece': '▁indian', 'id': 909, 'score': -9.14788818359375, 'type': 1},
#  {'piece': '▁probably', 'id': 910, 'score': -9.148329734802246, 'type': 1},
#  {'piece': 'ur', 'id': 911, 'score': -9.149774551391602, 'type': 1},
#  {'piece': '▁originally', 'id': 912, 'score': -9.149796485900879, 'type': 1},
#  {'piece': '▁maybe', 'id': 913, 'score': -9.150883674621582, 'type': 1},
#  {'piece': '▁germany', 'id': 914, 'score': -9.150948524475098, 'type': 1},
#  {'piece': 'my', 'id': 915, 'score': -9.151634216308594, 'type': 1},
#  {'piece': '▁songs', 'id': 916, 'score': -9.151660919189453, 'type': 1},
#  {'piece': '▁forward', 'id': 917, 'score': -9.151946067810059, 'type': 1},
#  {'piece': '12', 'id': 918, 'score': -9.15303897857666, 'type': 1},
#  {'piece': '▁cross', 'id': 919, 'score': -9.15399169921875, 'type': 1},
#  {'piece': '▁grand', 'id': 920, 'score': -9.155345916748047, 'type': 1},
#  {'piece': 'ko', 'id': 921, 'score': -9.15536880493164, 'type': 1},
#  {'piece': '▁charles', 'id': 922, 'score': -9.15537166595459, 'type': 1},
#  {'piece': 'less', 'id': 923, 'score': -9.15629768371582, 'type': 1},
#  {'piece': '▁areas', 'id': 924, 'score': -9.156498908996582, 'type': 1},
#  {'piece': '▁character', 'id': 925, 'score': -9.157135009765625, 'type': 1},
#  {'piece': '▁di', 'id': 926, 'score': -9.157842636108398, 'type': 1},
#  {'piece': '▁sir', 'id': 927, 'score': -9.15809154510498, 'type': 1},
#  {'piece': 'ri', 'id': 928, 'score': -9.158273696899414, 'type': 1},
#  {'piece': '▁appointed', 'id': 929, 'score': -9.158288955688477, 'type': 1},
#  {'piece': '▁talk', 'id': 930, 'score': -9.158649444580078, 'type': 1},
#  {'piece': '▁el', 'id': 931, 'score': -9.158790588378906, 'type': 1},
#  {'piece': '▁private', 'id': 932, 'score': -9.161293983459473, 'type': 1},
#  {'piece': '▁australian', 'id': 933, 'score': -9.161355018615723, 'type': 1},
#  {'piece': '▁institute', 'id': 934, 'score': -9.163350105285645, 'type': 1},
#  {'piece': '▁remained', 'id': 935, 'score': -9.164637565612793, 'type': 1},
#  {'piece': '▁peter', 'id': 936, 'score': -9.16519832611084, 'type': 1},
#  {'piece': '▁24', 'id': 937, 'score': -9.168376922607422, 'type': 1},
#  {'piece': '▁possible', 'id': 938, 'score': -9.168395042419434, 'type': 1},
#  {'piece': '▁sun', 'id': 939, 'score': -9.16844367980957, 'type': 1},
#  {'piece': '▁committee', 'id': 940, 'score': -9.16971492767334, 'type': 1},
#  {'piece': '▁media', 'id': 941, 'score': -9.17046070098877, 'type': 1},
#  {'piece': '▁episode', 'id': 942, 'score': -9.171656608581543, 'type': 1},
#  {'piece': '▁mark', 'id': 943, 'score': -9.171666145324707, 'type': 1},
#  {'piece': '▁plan', 'id': 944, 'score': -9.172432899475098, 'type': 1},
#  {'piece': '▁sold', 'id': 945, 'score': -9.173251152038574, 'type': 1},
#  {'piece': '▁running', 'id': 946, 'score': -9.17348861694336, 'type': 1},
#  {'piece': 'il', 'id': 947, 'score': -9.174314498901367, 'type': 1},
#  {'piece': '▁hill', 'id': 948, 'score': -9.176017761230469, 'type': 1},
#  {'piece': '▁study', 'id': 949, 'score': -9.176782608032227, 'type': 1},
#  {'piece': '▁food', 'id': 950, 'score': -9.180841445922852, 'type': 1},
#  {'piece': '▁usually', 'id': 951, 'score': -9.18262004852295, 'type': 1},
#  {'piece': '▁teams', 'id': 952, 'score': -9.182623863220215, 'type': 1},
#  {'piece': '▁process', 'id': 953, 'score': -9.182927131652832, 'type': 1},
#  {'piece': '▁friends', 'id': 954, 'score': -9.184569358825684, 'type': 1},
#  {'piece': '▁bridge', 'id': 955, 'score': -9.188033103942871, 'type': 1},
#  {'piece': '▁performance', 'id': 956, 'score': -9.188719749450684, 'type': 1},
#  {'piece': '▁smile', 'id': 957, 'score': -9.189361572265625, 'type': 1},
#  {'piece': '▁herself', 'id': 958, 'score': -9.19033145904541, 'type': 1},
#  {'piece': '▁morning', 'id': 959, 'score': -9.195133209228516, 'type': 1},
#  {'piece': 'com', 'id': 960, 'score': -9.19552993774414, 'type': 1},
#  {'piece': '▁1990', 'id': 961, 'score': -9.19662857055664, 'type': 1},
#  {'piece': '▁else', 'id': 962, 'score': -9.197264671325684, 'type': 1},
#  {'piece': '▁events', 'id': 963, 'score': -9.199602127075195, 'type': 1},
#  {'piece': '▁books', 'id': 964, 'score': -9.200331687927246, 'type': 1},
#  {'piece': '▁bank', 'id': 965, 'score': -9.201471328735352, 'type': 1},
#  {'piece': '▁strong', 'id': 966, 'score': -9.201663970947266, 'type': 1},
#  {'piece': '▁features', 'id': 967, 'score': -9.201790809631348, 'type': 1},
#  {'piece': '▁list', 'id': 968, 'score': -9.20302963256836, 'type': 1},
#  {'piece': 'ba', 'id': 969, 'score': -9.204939842224121, 'type': 1},
#  {'piece': '▁eight', 'id': 970, 'score': -9.20560359954834, 'type': 1},
#  {'piece': '▁province', 'id': 971, 'score': -9.205921173095703, 'type': 1},
#  {'piece': '▁sub', 'id': 972, 'score': -9.210132598876953, 'type': 1},
#  {'piece': '▁2003', 'id': 973, 'score': -9.211892127990723, 'type': 1},
#  {'piece': '▁hours', 'id': 974, 'score': -9.212929725646973, 'type': 1},
#  {'piece': '▁census', 'id': 975, 'score': -9.214776039123535, 'type': 1},
#  {'piece': '▁quickly', 'id': 976, 'score': -9.215818405151367, 'type': 1},
#  {'piece': '▁coach', 'id': 977, 'score': -9.216257095336914, 'type': 1},
#  {'piece': '▁range', 'id': 978, 'score': -9.216410636901855, 'type': 1},
#  {'piece': '▁whole', 'id': 979, 'score': -9.217300415039062, 'type': 1},
#  {'piece': '▁hospital', 'id': 980, 'score': -9.217759132385254, 'type': 1},
#  {'piece': '▁term', 'id': 981, 'score': -9.218688011169434, 'type': 1},
#  {'piece': '▁network', 'id': 982, 'score': -9.219202041625977, 'type': 1},
#  {'piece': '▁tv', 'id': 983, 'score': -9.219342231750488, 'type': 1},
#  {'piece': '▁guitar', 'id': 984, 'score': -9.220499992370605, 'type': 1},
#  {'piece': '▁believe', 'id': 985, 'score': -9.221556663513184, 'type': 1},
#  {'piece': '▁performed', 'id': 986, 'score': -9.221843719482422, 'type': 1},
#  {'piece': '▁lower', 'id': 987, 'score': -9.224970817565918, 'type': 1},
#  {'piece': '▁seat', 'id': 988, 'score': -9.225187301635742, 'type': 1},
#  {'piece': '▁official', 'id': 989, 'score': -9.2254638671875, 'type': 1},
#  {'piece': '▁hear', 'id': 990, 'score': -9.227096557617188, 'type': 1},
#  {'piece': '▁attack', 'id': 991, 'score': -9.22746753692627, 'type': 1},
#  {'piece': '▁myself', 'id': 992, 'score': -9.227622985839844, 'type': 1},
#  {'piece': '▁x', 'id': 993, 'score': -9.22830581665039, 'type': 1},
#  {'piece': 'ha', 'id': 994, 'score': -9.230331420898438, 'type': 1},
#  {'piece': '▁ship', 'id': 995, 'score': -9.230628967285156, 'type': 1},
#  {'piece': '▁news', 'id': 996, 'score': -9.232447624206543, 'type': 1},
#  {'piece': '▁beginning', 'id': 997, 'score': -9.235310554504395, 'type': 1},
#  {'piece': '▁china', 'id': 998, 'score': -9.235831260681152, 'type': 1},
#  {'piece': '▁shot', 'id': 999, 'score': -9.2384614944458, 'type': 1},
#  ...]
